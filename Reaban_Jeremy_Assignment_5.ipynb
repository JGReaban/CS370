# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 17
# Scores: (min: 17, avg: 17, max: 17)
#
# Run: 2, exploration: 0.8734200960253871, score: 30
# Scores: (min: 17, avg: 23.5, max: 30)
#
# Run: 3, exploration: 0.7901049725470279, score: 21
# Scores: (min: 17, avg: 22.666666666666668, max: 30)
#
# Run: 4, exploration: 0.736559652908221, score: 15
# Scores: (min: 15, avg: 20.75, max: 30)
#
# Run: 5, exploration: 0.6935613678313175, score: 13
# Scores: (min: 13, avg: 19.2, max: 30)
#
# Run: 6, exploration: 0.6401093727576664, score: 17
# Scores: (min: 13, avg: 18.833333333333332, max: 30)
#
# Run: 7, exploration: 0.6057704364907278, score: 12
# Scores: (min: 12, avg: 17.857142857142858, max: 30)
#
# Run: 8, exploration: 0.5819594443402982, score: 9
# Scores: (min: 9, avg: 16.75, max: 30)
#
# Run: 9, exploration: 0.5452463540625918, score: 14
# Scores: (min: 9, avg: 16.444444444444443, max: 30)
#
# Run: 10, exploration: 0.5159963842937159, score: 12
# Scores: (min: 9, avg: 16, max: 30)
#
# Run: 11, exploration: 0.4907693883854626, score: 11
# Scores: (min: 9, avg: 15.545454545454545, max: 30)
#
# Run: 12, exploration: 0.47147873742168567, score: 9
# Scores: (min: 9, avg: 15, max: 30)
#
# Run: 13, exploration: 0.4506816115185697, score: 10
# Scores: (min: 9, avg: 14.615384615384615, max: 30)
#
# Run: 14, exploration: 0.42650460709830135, score: 12
# Scores: (min: 9, avg: 14.428571428571429, max: 30)
#
# Run: 15, exploration: 0.4117990041127769, score: 8
# Scores: (min: 8, avg: 14, max: 30)
#
# Run: 16, exploration: 0.3877593341372176, score: 13
# Scores: (min: 8, avg: 13.9375, max: 30)
#
# Run: 17, exploration: 0.3706551064126331, score: 10
# Scores: (min: 8, avg: 13.705882352941176, max: 30)
#
# Run: 18, exploration: 0.3438081748424137, score: 16
# Scores: (min: 8, avg: 13.833333333333334, max: 30)
#
# Run: 19, exploration: 0.32864265128599696, score: 10
# Scores: (min: 8, avg: 13.631578947368421, max: 30)
#
# Run: 20, exploration: 0.31101247816653554, score: 12
# Scores: (min: 8, avg: 13.55, max: 30)
#
# Run: 21, exploration: 0.2913921604631864, score: 14
# Scores: (min: 8, avg: 13.571428571428571, max: 30)
#
# Run: 22, exploration: 0.2757603055760701, score: 12
# Scores: (min: 8, avg: 13.5, max: 30)
#
# Run: 23, exploration: 0.2609670281126685, score: 12
# Scores: (min: 8, avg: 13.434782608695652, max: 30)
#
# Run: 24, exploration: 0.2457325055235537, score: 13
# Scores: (min: 8, avg: 13.416666666666666, max: 30)
#
# Run: 25, exploration: 0.2290792429684691, score: 15
# Scores: (min: 8, avg: 13.48, max: 30)
#
# Run: 26, exploration: 0.21355457002808648, score: 15
# Scores: (min: 8, avg: 13.538461538461538, max: 30)
#
# Run: 27, exploration: 0.1756341724525918, score: 40
# Scores: (min: 8, avg: 14.518518518518519, max: 40)
#
# Run: 28, exploration: 0.15888051309497406, score: 21
# Scores: (min: 8, avg: 14.75, max: 40)
#
# Run: 29, exploration: 0.14372497725712216, score: 21
# Scores: (min: 8, avg: 14.96551724137931, max: 40)
#
# Run: 30, exploration: 0.13198501352907185, score: 18
# Scores: (min: 8, avg: 15.066666666666666, max: 40)
#
# Run: 31, exploration: 0.10746596228306791, score: 42
# Scores: (min: 8, avg: 15.935483870967742, max: 42)
#
# Run: 32, exploration: 0.0943346041173244, score: 27
# Scores: (min: 8, avg: 16.28125, max: 42)
#
# Run: 33, exploration: 0.07379076075438468, score: 50
# Scores: (min: 8, avg: 17.303030303030305, max: 50)
#
# Run: 34, exploration: 0.06038446427088321, score: 41
# Scores: (min: 8, avg: 18, max: 50)
#
# Run: 35, exploration: 0.041670929977297724, score: 75
# Scores: (min: 8, avg: 19.62857142857143, max: 75)
#
# Run: 36, exploration: 0.03461682084029365, score: 38
# Scores: (min: 8, avg: 20.13888888888889, max: 75)
#
# Run: 37, exploration: 0.028901347193857643, score: 37
# Scores: (min: 8, avg: 20.594594594594593, max: 75)
#
# Run: 38, exploration: 0.023181078627322618, score: 45
# Scores: (min: 8, avg: 21.236842105263158, max: 75)
#
# Run: 39, exploration: 0.018042124582040707, score: 51
# Scores: (min: 8, avg: 22, max: 75)
#
# Run: 40, exploration: 0.01506324653745902, score: 37
# Scores: (min: 8, avg: 22.375, max: 75)
#
# Run: 41, exploration: 0.012450754000684672, score: 39
# Scores: (min: 8, avg: 22.78048780487805, max: 75)
#
# Run: 42, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 23.523809523809526, max: 75)
#
# Run: 43, exploration: 0.01, score: 80
# Scores: (min: 8, avg: 24.837209302325583, max: 80)
#
# Run: 44, exploration: 0.01, score: 97
# Scores: (min: 8, avg: 26.477272727272727, max: 97)
#
# Run: 45, exploration: 0.01, score: 125
# Scores: (min: 8, avg: 28.666666666666668, max: 125)
#
# Run: 46, exploration: 0.01, score: 109
# Scores: (min: 8, avg: 30.41304347826087, max: 125)
#
# Run: 47, exploration: 0.01, score: 167
# Scores: (min: 8, avg: 33.319148936170215, max: 167)
#
# Run: 48, exploration: 0.01, score: 133
# Scores: (min: 8, avg: 35.395833333333336, max: 167)
#
# Run: 49, exploration: 0.01, score: 126
# Scores: (min: 8, avg: 37.244897959183675, max: 167)
#
# Run: 50, exploration: 0.01, score: 101
# Scores: (min: 8, avg: 38.52, max: 167)
#
# Run: 51, exploration: 0.01, score: 145
# Scores: (min: 8, avg: 40.6078431372549, max: 167)
#
# Run: 52, exploration: 0.01, score: 211
# Scores: (min: 8, avg: 43.88461538461539, max: 211)
#
# Run: 53, exploration: 0.01, score: 138
# Scores: (min: 8, avg: 45.660377358490564, max: 211)
#
# Run: 54, exploration: 0.01, score: 158
# Scores: (min: 8, avg: 47.74074074074074, max: 211)
#
# Run: 55, exploration: 0.01, score: 142
# Scores: (min: 8, avg: 49.45454545454545, max: 211)
#
# Run: 56, exploration: 0.01, score: 182
# Scores: (min: 8, avg: 51.82142857142857, max: 211)
#
# Run: 57, exploration: 0.01, score: 198
# Scores: (min: 8, avg: 54.3859649122807, max: 211)
#
# Run: 58, exploration: 0.01, score: 205
# Scores: (min: 8, avg: 56.98275862068966, max: 211)
#
# Run: 59, exploration: 0.01, score: 271
# Scores: (min: 8, avg: 60.610169491525426, max: 271)
#
# Run: 60, exploration: 0.01, score: 240
# Scores: (min: 8, avg: 63.6, max: 271)
#
# Run: 61, exploration: 0.01, score: 186
# Scores: (min: 8, avg: 65.60655737704919, max: 271)
#
# Run: 62, exploration: 0.01, score: 372
# Scores: (min: 8, avg: 70.54838709677419, max: 372)
#
# Run: 63, exploration: 0.01, score: 249
# Scores: (min: 8, avg: 73.38095238095238, max: 372)
#
# Run: 64, exploration: 0.01, score: 380
# Scores: (min: 8, avg: 78.171875, max: 380)
#
# Run: 65, exploration: 0.01, score: 300
# Scores: (min: 8, avg: 81.58461538461539, max: 380)
#
# Run: 66, exploration: 0.01, score: 294
# Scores: (min: 8, avg: 84.8030303030303, max: 380)
#
# Run: 67, exploration: 0.01, score: 209
# Scores: (min: 8, avg: 86.65671641791045, max: 380)
#
# Run: 68, exploration: 0.01, score: 206
# Scores: (min: 8, avg: 88.41176470588235, max: 380)
#
# Run: 69, exploration: 0.01, score: 162
# Scores: (min: 8, avg: 89.47826086956522, max: 380)
#
# Run: 70, exploration: 0.01, score: 227
# Scores: (min: 8, avg: 91.44285714285714, max: 380)
#
# Run: 71, exploration: 0.01, score: 214
# Scores: (min: 8, avg: 93.16901408450704, max: 380)
#
# Run: 72, exploration: 0.01, score: 199
# Scores: (min: 8, avg: 94.63888888888889, max: 380)
#
# Run: 73, exploration: 0.01, score: 217
# Scores: (min: 8, avg: 96.31506849315069, max: 380)
#
# Run: 74, exploration: 0.01, score: 204
# Scores: (min: 8, avg: 97.77027027027027, max: 380)
#
# Run: 75, exploration: 0.01, score: 225
# Scores: (min: 8, avg: 99.46666666666667, max: 380)
#
# Run: 76, exploration: 0.01, score: 260
# Scores: (min: 8, avg: 101.57894736842105, max: 380)
#
# Run: 77, exploration: 0.01, score: 160
# Scores: (min: 8, avg: 102.33766233766234, max: 380)
#
# Run: 78, exploration: 0.01, score: 231
# Scores: (min: 8, avg: 103.98717948717949, max: 380)
#
# Run: 79, exploration: 0.01, score: 196
# Scores: (min: 8, avg: 105.15189873417721, max: 380)
#
# Run: 80, exploration: 0.01, score: 311
# Scores: (min: 8, avg: 107.725, max: 380)
#
# Run: 81, exploration: 0.01, score: 229
# Scores: (min: 8, avg: 109.22222222222223, max: 380)
#
# Run: 82, exploration: 0.01, score: 192
# Scores: (min: 8, avg: 110.23170731707317, max: 380)
#
# Run: 83, exploration: 0.01, score: 245
# Scores: (min: 8, avg: 111.855421686747, max: 380)
#
# Run: 84, exploration: 0.01, score: 180
# Scores: (min: 8, avg: 112.66666666666667, max: 380)
#
# Run: 85, exploration: 0.01, score: 327
# Scores: (min: 8, avg: 115.18823529411765, max: 380)
#
# Run: 86, exploration: 0.01, score: 160
# Scores: (min: 8, avg: 115.70930232558139, max: 380)
#
# Run: 87, exploration: 0.01, score: 132
# Scores: (min: 8, avg: 115.89655172413794, max: 380)
#
# Run: 88, exploration: 0.01, score: 295
# Scores: (min: 8, avg: 117.93181818181819, max: 380)
# Run: 89, exploration: 0.01, score: 246
# Scores: (min: 8, avg: 119.37078651685393, max: 380)
#
# Run: 90, exploration: 0.01, score: 230
# Scores: (min: 8, avg: 120.6, max: 380)
#
# Run: 91, exploration: 0.01, score: 193
# Scores: (min: 8, avg: 121.3956043956044, max: 380)
#
# Run: 92, exploration: 0.01, score: 254
# Scores: (min: 8, avg: 122.83695652173913, max: 380)
#
# Run: 93, exploration: 0.01, score: 117
# Scores: (min: 8, avg: 122.7741935483871, max: 380)
#
# Run: 94, exploration: 0.01, score: 266
# Scores: (min: 8, avg: 124.29787234042553, max: 380)
#
# Run: 95, exploration: 0.01, score: 217
# Scores: (min: 8, avg: 125.27368421052631, max: 380)
#
# Run: 96, exploration: 0.01, score: 134
# Scores: (min: 8, avg: 125.36458333333333, max: 380)
#
# Run: 97, exploration: 0.01, score: 139
# Scores: (min: 8, avg: 125.50515463917526, max: 380)
#
# Run: 98, exploration: 0.01, score: 162
# Scores: (min: 8, avg: 125.87755102040816, max: 380)
#
# Run: 99, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 129.65656565656565, max: 500)
#
# Run: 100, exploration: 0.01, score: 186
# Scores: (min: 8, avg: 130.22, max: 500)
#
# Run: 101, exploration: 0.01, score: 243
# Scores: (min: 8, avg: 132.48, max: 500)
#
# Run: 102, exploration: 0.01, score: 212
# Scores: (min: 8, avg: 134.3, max: 500)
#
# Run: 103, exploration: 0.01, score: 163
# Scores: (min: 8, avg: 135.72, max: 500)
#
# Run: 104, exploration: 0.01, score: 245
# Scores: (min: 8, avg: 138.02, max: 500)
#
# Run: 105, exploration: 0.01, score: 238
# Scores: (min: 8, avg: 140.27, max: 500)
#
# Run: 106, exploration: 0.01, score: 261
# Scores: (min: 8, avg: 142.71, max: 500)
#
# Run: 107, exploration: 0.01, score: 251
# Scores: (min: 8, avg: 145.1, max: 500)
#
# Run: 108, exploration: 0.01, score: 304
# Scores: (min: 8, avg: 148.05, max: 500)
#
# Run: 109, exploration: 0.01, score: 387
# Scores: (min: 8, avg: 151.78, max: 500)
#
# Run: 110, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 156.66, max: 500)
#
# Run: 111, exploration: 0.01, score: 476
# Scores: (min: 8, avg: 161.31, max: 500)
#
# Run: 112, exploration: 0.01, score: 264
# Scores: (min: 8, avg: 163.86, max: 500)
#
# Run: 113, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 164.12, max: 500)
#
# Run: 114, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 164.11, max: 500)
#
# Run: 115, exploration: 0.01, score: 18
# Scores: (min: 10, avg: 164.21, max: 500)
#
# Run: 116, exploration: 0.01, score: 264
# Scores: (min: 10, avg: 166.72, max: 500)
#
# Run: 117, exploration: 0.01, score: 64
# Scores: (min: 10, avg: 167.26, max: 500)
#
# Run: 118, exploration: 0.01, score: 260
# Scores: (min: 10, avg: 169.7, max: 500)
#
# Run: 119, exploration: 0.01, score: 38
# Scores: (min: 11, avg: 169.98, max: 500)
#
# Run: 120, exploration: 0.01, score: 191
# Scores: (min: 11, avg: 171.77, max: 500)
#
# Run: 121, exploration: 0.01, score: 143
# Scores: (min: 11, avg: 173.06, max: 500)
#
# Run: 122, exploration: 0.01, score: 220
# Scores: (min: 11, avg: 175.14, max: 500)
#
# Run: 123, exploration: 0.01, score: 102
# Scores: (min: 11, avg: 176.04, max: 500)
#
# Run: 124, exploration: 0.01, score: 145
# Scores: (min: 11, avg: 177.36, max: 500)
#
# Run: 125, exploration: 0.01, score: 15
# Scores: (min: 11, avg: 177.36, max: 500)
#
# Run: 126, exploration: 0.01, score: 269
# Scores: (min: 11, avg: 179.9, max: 500)
#
# Run: 127, exploration: 0.01, score: 379
# Scores: (min: 11, avg: 183.29, max: 500)
#
# Run: 128, exploration: 0.01, score: 67
# Scores: (min: 11, avg: 183.75, max: 500)
#
# Run: 129, exploration: 0.01, score: 147
# Scores: (min: 11, avg: 185.01, max: 500)
#
# Run: 130, exploration: 0.01, score: 28
# Scores: (min: 11, avg: 185.11, max: 500)
#
# Run: 131, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 184.79, max: 500)
#
# Run: 132, exploration: 0.01, score: 16
# Scores: (min: 10, avg: 184.68, max: 500)
#
# Run: 133, exploration: 0.01, score: 151
# Scores: (min: 10, avg: 185.69, max: 500)
#
# Run: 134, exploration: 0.01, score: 25
# Scores: (min: 10, avg: 185.53, max: 500)
#
# Run: 135, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 184.89, max: 500)
#
# Run: 136, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 184.63, max: 500)
#
# Run: 137, exploration: 0.01, score: 15
# Scores: (min: 10, avg: 184.41, max: 500)
#
# Run: 138, exploration: 0.01, score: 369
# Scores: (min: 10, avg: 187.65, max: 500)
#
# Run: 139, exploration: 0.01, score: 340
# Scores: (min: 10, avg: 190.54, max: 500)
#
# Run: 140, exploration: 0.01, score: 161
# Scores: (min: 10, avg: 191.78, max: 500)
#
# Run: 141, exploration: 0.01, score: 273
# Scores: (min: 10, avg: 194.12, max: 500)
#
# Run: 142, exploration: 0.01, score: 325
# Scores: (min: 10, avg: 196.83, max: 500)
#
# Solved in 42 runs, 142 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-3-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# Note: If the code is running properly, you should begin to see output appearing above this code block. It will take several minutes, so it is recommended that you let this code run in the background while completing other work. When the code has finished, it will print output saying, "Solved in _ runs, _ total runs."
#
# You may see an error about not having an exit command. This error does not affect the program's functionality and results from the steps taken to convert the code from Python 2.x to Python 3. Please disregard this error.

# %%
# This wll modify the Discoutn Factor, aka Gamma to see how the results change
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
## changed Gamma from .95 to .70 and resulted in 900+ runs with no solution 
##  now try .99
GAMMA = 0.99 
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()
# Out:
# Using TensorFlow backend.

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 16
# Scores: (min: 16, avg: 16, max: 16)
#
# Run: 2, exploration: 0.946354579813443, score: 15
# Scores: (min: 15, avg: 15.5, max: 16)
#
# Run: 3, exploration: 0.8647077305675338, score: 19
# Scores: (min: 15, avg: 16.666666666666668, max: 19)
#
# Run: 4, exploration: 0.8265651079747222, score: 10
# Scores: (min: 10, avg: 15, max: 19)
#
# Run: 5, exploration: 0.7705488893118823, score: 15
# Scores: (min: 10, avg: 15, max: 19)
#
# Run: 6, exploration: 0.7402609576967045, score: 9
# Scores: (min: 9, avg: 14, max: 19)
#
# Run: 7, exploration: 0.7005493475733617, score: 12
# Scores: (min: 9, avg: 13.714285714285714, max: 19)
#
# Run: 8, exploration: 0.6662995813682115, score: 11
# Scores: (min: 9, avg: 13.375, max: 19)
#
# Run: 9, exploration: 0.6305556603555866, score: 12
# Scores: (min: 9, avg: 13.222222222222221, max: 19)
#
# Run: 10, exploration: 0.5937455908197752, score: 13
# Scores: (min: 9, avg: 13.2, max: 19)
#
# Run: 11, exploration: 0.5647174463480732, score: 11
# Scores: (min: 9, avg: 13, max: 19)
#
# Run: 12, exploration: 0.5425201222922789, score: 9
# Scores: (min: 9, avg: 12.666666666666666, max: 19)
#
# Run: 13, exploration: 0.47622912292284103, score: 27
# Scores: (min: 9, avg: 13.76923076923077, max: 27)
#
# Run: 14, exploration: 0.2884855236625661, score: 101
# Scores: (min: 9, avg: 20, max: 101)
#
# Run: 15, exploration: 0.20209834538617025, score: 72
# Scores: (min: 9, avg: 23.466666666666665, max: 101)
#
# Run: 16, exploration: 0.16957841978827493, score: 36
# Scores: (min: 9, avg: 24.25, max: 101)
#
# Run: 17, exploration: 0.14590259167570602, score: 31
# Scores: (min: 9, avg: 24.647058823529413, max: 101)
#
# Run: 18, exploration: 0.1135578192100607, score: 51
# Scores: (min: 9, avg: 26.11111111111111, max: 101)
#
# Run: 19, exploration: 0.05978212923978115, score: 129
# Scores: (min: 9, avg: 31.526315789473685, max: 129)
#
# Run: 20, exploration: 0.046997986793891174, score: 49
# Scores: (min: 9, avg: 32.4, max: 129)
#
# Run: 21, exploration: 0.03392965965983891, score: 66
# Scores: (min: 9, avg: 34, max: 129)
#
# Run: 22, exploration: 0.024991218342344988, score: 62
# Scores: (min: 9, avg: 35.27272727272727, max: 129)
#
# Run: 23, exploration: 0.016988875991640028, score: 78
# Scores: (min: 9, avg: 37.130434782608695, max: 129)
#
# Run: 24, exploration: 0.012388500230681249, score: 64
# Scores: (min: 9, avg: 38.25, max: 129)
#
# Run: 25, exploration: 0.01, score: 61
# Scores: (min: 9, avg: 39.16, max: 129)
#
# Run: 26, exploration: 0.01, score: 68
# Scores: (min: 9, avg: 40.26923076923077, max: 129)
#
# Run: 27, exploration: 0.01, score: 116
# Scores: (min: 9, avg: 43.074074074074076, max: 129)
#
# Run: 28, exploration: 0.01, score: 90
# Scores: (min: 9, avg: 44.75, max: 129)
#
# Run: 29, exploration: 0.01, score: 346
# Scores: (min: 9, avg: 55.13793103448276, max: 346)
#
# Run: 30, exploration: 0.01, score: 128
# Scores: (min: 9, avg: 57.56666666666667, max: 346)
#
# Run: 31, exploration: 0.01, score: 123
# Scores: (min: 9, avg: 59.67741935483871, max: 346)
#
# Run: 32, exploration: 0.01, score: 425
# Scores: (min: 9, avg: 71.09375, max: 425)
#
# Run: 33, exploration: 0.01, score: 160
# Scores: (min: 9, avg: 73.78787878787878, max: 425)
#
# Run: 34, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 72.08823529411765, max: 425)
#
# Run: 35, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 70.34285714285714, max: 425)
#
# Run: 36, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 68.66666666666667, max: 425)
#
# Run: 37, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 67.08108108108108, max: 425)
#
# Run: 38, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 65.57894736842105, max: 425)
#
# Run: 39, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 64.17948717948718, max: 425)
#
# Run: 40, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 62.8, max: 425)
#
# Run: 41, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 61.51219512195122, max: 425)
#
# Run: 42, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 60.26190476190476, max: 425)
#
# Run: 43, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 59.06976744186046, max: 425)
#
# Run: 44, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 57.97727272727273, max: 425)
#
# Run: 45, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 57.022222222222226, max: 425)
#
# Run: 46, exploration: 0.01, score: 27
# Scores: (min: 9, avg: 56.369565217391305, max: 425)
#
# Run: 47, exploration: 0.01, score: 57
# Scores: (min: 9, avg: 56.38297872340426, max: 425)
#
# Run: 48, exploration: 0.01, score: 310
# Scores: (min: 9, avg: 61.666666666666664, max: 425)
#
# Run: 49, exploration: 0.01, score: 84
# Scores: (min: 9, avg: 62.12244897959184, max: 425)
#
# Run: 50, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 70.88, max: 500)
#
# Run: 51, exploration: 0.01, score: 322
# Scores: (min: 9, avg: 75.80392156862744, max: 500)
#
# Run: 52, exploration: 0.01, score: 362
# Scores: (min: 9, avg: 81.3076923076923, max: 500)
#
# Run: 53, exploration: 0.01, score: 461
# Scores: (min: 9, avg: 88.47169811320755, max: 500)
#
# Run: 54, exploration: 0.01, score: 269
# Scores: (min: 9, avg: 91.81481481481481, max: 500)
#
# Run: 55, exploration: 0.01, score: 249
# Scores: (min: 9, avg: 94.67272727272727, max: 500)
#
# Run: 56, exploration: 0.01, score: 246
# Scores: (min: 9, avg: 97.375, max: 500)
#
# Run: 57, exploration: 0.01, score: 239
# Scores: (min: 9, avg: 99.85964912280701, max: 500)
#
# Run: 58, exploration: 0.01, score: 227
# Scores: (min: 9, avg: 102.05172413793103, max: 500)
#
# Run: 59, exploration: 0.01, score: 193
# Scores: (min: 9, avg: 103.59322033898304, max: 500)
#
# Run: 60, exploration: 0.01, score: 486
# Scores: (min: 9, avg: 109.96666666666667, max: 500)
#
# Run: 61, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 108.32786885245902, max: 500)
#
# Run: 62, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 106.74193548387096, max: 500)
#
# Run: 63, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 105.19047619047619, max: 500)
#
# Run: 64, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 103.6875, max: 500)
#
# Run: 65, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 102.23076923076923, max: 500)
#
# Run: 66, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 100.8030303030303, max: 500)
#
# Run: 67, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 99.44776119402985, max: 500)
#
# Run: 68, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 98.11764705882354, max: 500)
#
# Run: 69, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 96.82608695652173, max: 500)
#
# Run: 70, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 95.6, max: 500)
#
# Run: 71, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 94.3943661971831, max: 500)
#
# Run: 72, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 93.22222222222223, max: 500)
#
# Run: 73, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 92.08219178082192, max: 500)
#
# Run: 74, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 90.95945945945945, max: 500)
#
# Run: 75, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 89.88, max: 500)
#
# Run: 76, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 88.80263157894737, max: 500)
#
# Run: 77, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 87.77922077922078, max: 500)
#
# Run: 78, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 86.75641025641026, max: 500)
#
# Run: 79, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 85.78481012658227, max: 500)
#
# Run: 80, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 84.825, max: 500)
#
# Run: 81, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 83.90123456790124, max: 500)
#
# Run: 82, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 83, max: 500)
#
# Run: 83, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 82.10843373493977, max: 500)
#
# Run: 84, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 81.25, max: 500)
#
# Run: 85, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 80.4, max: 500)
#
# Run: 86, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 79.5813953488372, max: 500)
#
# Run: 87, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 78.7816091954023, max: 500)
#
# Run: 88, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 78, max: 500)
#
# Run: 89, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 77.23595505617978, max: 500)
#
# Run: 90, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 76.4888888888889, max: 500)
#
# Run: 91, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 75.75824175824175, max: 500)
#
# Run: 92, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 75.04347826086956, max: 500)
# Run: 93, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 74.34408602150538, max: 500)
#
# Run: 94, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 73.63829787234043, max: 500)
#
# Run: 95, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 72.9578947368421, max: 500)
#
# Run: 96, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 72.29166666666667, max: 500)
#
# Run: 97, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 71.64948453608247, max: 500)
#
# Run: 98, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 71.0204081632653, max: 500)
#
# Run: 99, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 70.42424242424242, max: 500)
#
# Run: 100, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 69.81, max: 500)
#
# Run: 101, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 69.75, max: 500)
#
# Run: 102, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 69.69, max: 500)
#
# Run: 103, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 69.58, max: 500)
#
# Run: 104, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 69.57, max: 500)
#
# Run: 105, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 69.5, max: 500)
#
# Run: 106, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 69.5, max: 500)
#
# Run: 107, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 69.48, max: 500)
#
# Run: 108, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 69.46, max: 500)
#
# Run: 109, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 69.45, max: 500)
#
# Run: 110, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 69.42, max: 500)
#
# Run: 111, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 69.4, max: 500)
#
# Run: 112, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 69.39, max: 500)
#
# Run: 113, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 69.21, max: 500)
#
# Run: 114, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 68.3, max: 500)
#
# Run: 115, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 68.07, max: 500)
#
# Run: 116, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 67.88, max: 500)
#
# Run: 117, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 67.7, max: 500)
#
# Run: 118, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 67.33, max: 500)
#
# Run: 119, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 66.17, max: 500)
#
# Run: 120, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 65.81, max: 500)
#
# Run: 121, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 65.25, max: 500)
#
# Run: 122, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 64.73, max: 500)
#
# Run: 123, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 64.04, max: 500)
#
# Run: 124, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 63.48, max: 500)
#
# Run: 125, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 62.97, max: 500)
#
# Run: 126, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 62.42, max: 500)
#
# Run: 127, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 61.38, max: 500)
#
# Run: 128, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 60.58, max: 500)
#
# Run: 129, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 57.23, max: 500)
#
# Run: 130, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 56.06, max: 500)
#
# Run: 131, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 54.92, max: 500)
#
# Run: 132, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 50.77, max: 500)
#
# Run: 133, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 49.27, max: 500)
#
# Run: 134, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 49.21, max: 500)
#
# Run: 135, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 49.19, max: 500)
#
# Run: 136, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 49.18, max: 500)
#
# Run: 137, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 49.17, max: 500)
#
# Run: 138, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 49.16, max: 500)
#
# Run: 139, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 49.15, max: 500)
#
# Run: 140, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 49.16, max: 500)
#
# Run: 141, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 49.15, max: 500)
#
# Run: 142, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 49.17, max: 500)
#
# Run: 143, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 49.17, max: 500)
#
# Run: 144, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 49.16, max: 500)
#
# Run: 145, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 49.11, max: 500)
#
# Run: 146, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 48.95, max: 500)
#
# Run: 147, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 48.47, max: 500)
#
# Run: 148, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 45.48, max: 500)
#
# Run: 149, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 44.74, max: 500)
#
# Run: 150, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 39.85, max: 486)
#
# Run: 151, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 36.72, max: 486)
#
# Run: 152, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 33.2, max: 486)
#
# Run: 153, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 28.69, max: 486)
#
# Run: 154, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 26.08, max: 486)
#
# Run: 155, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 23.69, max: 486)
#
# Run: 156, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 21.33, max: 486)
#
# Run: 157, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 19.02, max: 486)
#
# Run: 158, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.85, max: 486)
#
# Run: 159, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.01, max: 486)
#
# Run: 160, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.23, max: 49)
#
# Run: 161, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.23, max: 49)
#
# Run: 162, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.24, max: 49)
#
# Run: 163, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.26, max: 49)
#
# Run: 164, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.25, max: 49)
#
# Run: 165, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.27, max: 49)
#
# Run: 166, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.3, max: 49)
#
# Run: 167, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.31, max: 49)
#
# Run: 168, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.31, max: 49)
#
# Run: 169, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.33, max: 49)
#
# Run: 170, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.32, max: 49)
#
# Run: 171, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.32, max: 49)
#
# Run: 172, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.32, max: 49)
#
# Run: 173, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.31, max: 49)
#
# Run: 174, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.34, max: 49)
#
# Run: 175, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.37, max: 49)
#
# Run: 176, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.41, max: 49)
#
# Run: 177, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.42, max: 49)
#
# Run: 178, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 10.49, max: 49)
#
# Run: 179, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 10.6, max: 49)
#
# Run: 180, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 10.71, max: 49)
#
# Run: 181, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 10.92, max: 49)
#
# Run: 182, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 11.07, max: 49)
#
# Run: 183, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 11.21, max: 49)
#
# Run: 184, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 11.33, max: 49)
#
# Run: 185, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 11.5, max: 49)
#
# Run: 186, exploration: 0.01, score: 65
# Scores: (min: 8, avg: 12.05, max: 65)
#
# Run: 187, exploration: 0.01, score: 239
# Scores: (min: 8, avg: 14.34, max: 239)
#
# Run: 188, exploration: 0.01, score: 433
# Scores: (min: 8, avg: 18.57, max: 433)
#
# Run: 189, exploration: 0.01, score: 342
# Scores: (min: 8, avg: 21.89, max: 433)
#
# Run: 190, exploration: 0.01, score: 243
# Scores: (min: 8, avg: 24.22, max: 433)
#
# Run: 191, exploration: 0.01, score: 373
# Scores: (min: 8, avg: 27.85, max: 433)
#
# Run: 192, exploration: 0.01, score: 198
# Scores: (min: 8, avg: 29.73, max: 433)
#
# Run: 193, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 34.63, max: 500)
#
# Run: 194, exploration: 0.01, score: 292
# Scores: (min: 8, avg: 37.47, max: 500)
#
# Run: 195, exploration: 0.01, score: 226
# Scores: (min: 8, avg: 39.64, max: 500)
#
# Run: 196, exploration: 0.01, score: 220
# Scores: (min: 8, avg: 41.75, max: 500)
# Run: 197, exploration: 0.01, score: 281
# Scores: (min: 8, avg: 44.46, max: 500)
#
# Run: 198, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 49.36, max: 500)
#
# Run: 199, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 54.24, max: 500)
#
# Run: 200, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 59.15, max: 500)
#
# Run: 201, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 64.05, max: 500)
#
# Run: 202, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 68.96, max: 500)
#
# Run: 203, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 73.88, max: 500)
#
# Run: 204, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 78.79, max: 500)
#
# Run: 205, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 83.71, max: 500)
#
# Run: 206, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 88.62, max: 500)
#
# Run: 207, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 93.52, max: 500)
#
# Run: 208, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 98.43, max: 500)
#
# Run: 209, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 103.32, max: 500)
#
# Run: 210, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 108.22, max: 500)
#
# Run: 211, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 113.13, max: 500)
#
# Run: 212, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 118.05, max: 500)
#
# Run: 213, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 122.96, max: 500)
#
# Run: 214, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 127.86, max: 500)
#
# Run: 215, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 132.37, max: 500)
#
# Run: 216, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 137.2, max: 500)
#
# Run: 217, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 142.07, max: 500)
#
# Run: 218, exploration: 0.01, score: 195
# Scores: (min: 8, avg: 143.88, max: 500)
#
# Run: 219, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 148.75, max: 500)
#
# Run: 220, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 153.62, max: 500)
#
# Run: 221, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 158.52, max: 500)
#
# Run: 222, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 163.42, max: 500)
#
# Run: 223, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 168.33, max: 500)
#
# Run: 224, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 173.25, max: 500)
#
# Run: 225, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 178.15, max: 500)
#
# Run: 226, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 183.02, max: 500)
#
# Run: 227, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 187.9, max: 500)
#
# Run: 228, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 192.8, max: 500)
#
# Run: 229, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 197.69, max: 500)
#
# Solved in 129 runs, 229 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-1-e6ab186dca9f> in cartpole()
#      86             if terminal:
#      87                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 88                 score_logger.add_score(step, run)
#      89                 break
#      90             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
# This run will vary the learning rate
#
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
# changing the learning rate from .001 to .002
# doing a small increment since the last big increment change took too long
LEARNING_RATE = 0.002  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 16
# Scores: (min: 16, avg: 16, max: 16)
#
# Run: 2, exploration: 0.9416228069143757, score: 16
# Scores: (min: 16, avg: 16, max: 16)
#
# Run: 3, exploration: 0.9000874278732445, score: 10
# Scores: (min: 10, avg: 14, max: 16)
#
# Run: 4, exploration: 0.8603841919146962, score: 10
# Scores: (min: 10, avg: 13, max: 16)
#
# Run: 5, exploration: 0.8061065909263957, score: 14
# Scores: (min: 10, avg: 13.2, max: 16)
#
# Run: 6, exploration: 0.736559652908221, score: 19
# Scores: (min: 10, avg: 14.166666666666666, max: 19)
#
# Run: 7, exploration: 0.6149486215357263, score: 37
# Scores: (min: 10, avg: 17.428571428571427, max: 37)
#
# Run: 8, exploration: 0.567555222460375, score: 17
# Scores: (min: 10, avg: 17.375, max: 37)
#
# Run: 9, exploration: 0.5290920728090721, score: 15
# Scores: (min: 10, avg: 17.11111111111111, max: 37)
#
# Run: 10, exploration: 0.4529463432347434, score: 32
# Scores: (min: 10, avg: 18.6, max: 37)
#
# Run: 11, exploration: 0.31890579420988907, score: 71
# Scores: (min: 10, avg: 23.363636363636363, max: 71)
#
# Run: 12, exploration: 0.26759021970270175, score: 36
# Scores: (min: 10, avg: 24.416666666666668, max: 71)
#
# Run: 13, exploration: 0.2178795886667409, score: 42
# Scores: (min: 10, avg: 25.76923076923077, max: 71)
#
# Run: 14, exploration: 0.14300635237083656, score: 85
# Scores: (min: 10, avg: 30, max: 85)
#
# Run: 15, exploration: 0.08448484422350626, score: 106
# Scores: (min: 10, avg: 35.06666666666667, max: 106)
#
# Run: 16, exploration: 0.043812938841152796, score: 132
# Scores: (min: 10, avg: 41.125, max: 132)
#
# Run: 17, exploration: 0.030083851847510768, score: 76
# Scores: (min: 10, avg: 43.1764705882353, max: 132)
#
# Run: 18, exploration: 0.018874695352408037, score: 94
# Scores: (min: 10, avg: 46, max: 132)
#
# Run: 19, exploration: 0.012576201611761997, score: 82
# Scores: (min: 10, avg: 47.89473684210526, max: 132)
#
# Run: 20, exploration: 0.01, score: 92
# Scores: (min: 10, avg: 50.1, max: 132)
#
# Run: 21, exploration: 0.01, score: 101
# Scores: (min: 10, avg: 52.523809523809526, max: 132)
#
# Run: 22, exploration: 0.01, score: 103
# Scores: (min: 10, avg: 54.81818181818182, max: 132)
#
# Run: 23, exploration: 0.01, score: 141
# Scores: (min: 10, avg: 58.56521739130435, max: 141)
#
# Run: 24, exploration: 0.01, score: 127
# Scores: (min: 10, avg: 61.416666666666664, max: 141)
#
# Run: 25, exploration: 0.01, score: 181
# Scores: (min: 10, avg: 66.2, max: 181)
#
# Run: 26, exploration: 0.01, score: 146
# Scores: (min: 10, avg: 69.26923076923077, max: 181)
#
# Run: 27, exploration: 0.01, score: 124
# Scores: (min: 10, avg: 71.29629629629629, max: 181)
#
# Run: 28, exploration: 0.01, score: 117
# Scores: (min: 10, avg: 72.92857142857143, max: 181)
#
# Run: 29, exploration: 0.01, score: 150
# Scores: (min: 10, avg: 75.58620689655173, max: 181)
#
# Run: 30, exploration: 0.01, score: 132
# Scores: (min: 10, avg: 77.46666666666667, max: 181)
#
# Run: 31, exploration: 0.01, score: 105
# Scores: (min: 10, avg: 78.35483870967742, max: 181)
#
# Run: 32, exploration: 0.01, score: 119
# Scores: (min: 10, avg: 79.625, max: 181)
#
# Run: 33, exploration: 0.01, score: 108
# Scores: (min: 10, avg: 80.48484848484848, max: 181)
#
# Run: 34, exploration: 0.01, score: 141
# Scores: (min: 10, avg: 82.26470588235294, max: 181)
#
# Run: 35, exploration: 0.01, score: 110
# Scores: (min: 10, avg: 83.05714285714286, max: 181)
#
# Run: 36, exploration: 0.01, score: 149
# Scores: (min: 10, avg: 84.88888888888889, max: 181)
#
# Run: 37, exploration: 0.01, score: 124
# Scores: (min: 10, avg: 85.94594594594595, max: 181)
#
# Run: 38, exploration: 0.01, score: 112
# Scores: (min: 10, avg: 86.63157894736842, max: 181)
#
# Run: 39, exploration: 0.01, score: 121
# Scores: (min: 10, avg: 87.51282051282051, max: 181)
#
# Run: 40, exploration: 0.01, score: 115
# Scores: (min: 10, avg: 88.2, max: 181)
#
# Run: 41, exploration: 0.01, score: 126
# Scores: (min: 10, avg: 89.1219512195122, max: 181)
#
# Run: 42, exploration: 0.01, score: 136
# Scores: (min: 10, avg: 90.23809523809524, max: 181)
#
# Run: 43, exploration: 0.01, score: 118
# Scores: (min: 10, avg: 90.88372093023256, max: 181)
#
# Run: 44, exploration: 0.01, score: 124
# Scores: (min: 10, avg: 91.63636363636364, max: 181)
#
# Run: 45, exploration: 0.01, score: 115
# Scores: (min: 10, avg: 92.15555555555555, max: 181)
#
# Run: 46, exploration: 0.01, score: 107
# Scores: (min: 10, avg: 92.47826086956522, max: 181)
#
# Run: 47, exploration: 0.01, score: 18
# Scores: (min: 10, avg: 90.8936170212766, max: 181)
#
# Run: 48, exploration: 0.01, score: 32
# Scores: (min: 10, avg: 89.66666666666667, max: 181)
#
# Run: 49, exploration: 0.01, score: 112
# Scores: (min: 10, avg: 90.12244897959184, max: 181)
#
# Run: 50, exploration: 0.01, score: 127
# Scores: (min: 10, avg: 90.86, max: 181)
#
# Run: 51, exploration: 0.01, score: 121
# Scores: (min: 10, avg: 91.45098039215686, max: 181)
#
# Run: 52, exploration: 0.01, score: 104
# Scores: (min: 10, avg: 91.6923076923077, max: 181)
#
# Run: 53, exploration: 0.01, score: 102
# Scores: (min: 10, avg: 91.88679245283019, max: 181)
#
# Run: 54, exploration: 0.01, score: 139
# Scores: (min: 10, avg: 92.75925925925925, max: 181)
#
# Run: 55, exploration: 0.01, score: 108
# Scores: (min: 10, avg: 93.03636363636363, max: 181)
#
# Run: 56, exploration: 0.01, score: 112
# Scores: (min: 10, avg: 93.375, max: 181)
#
# Run: 57, exploration: 0.01, score: 95
# Scores: (min: 10, avg: 93.40350877192982, max: 181)
#
# Run: 58, exploration: 0.01, score: 131
# Scores: (min: 10, avg: 94.05172413793103, max: 181)
#
# Run: 59, exploration: 0.01, score: 122
# Scores: (min: 10, avg: 94.52542372881356, max: 181)
#
# Run: 60, exploration: 0.01, score: 164
# Scores: (min: 10, avg: 95.68333333333334, max: 181)
#
# Run: 61, exploration: 0.01, score: 103
# Scores: (min: 10, avg: 95.80327868852459, max: 181)
#
# Run: 62, exploration: 0.01, score: 127
# Scores: (min: 10, avg: 96.30645161290323, max: 181)
#
# Run: 63, exploration: 0.01, score: 102
# Scores: (min: 10, avg: 96.39682539682539, max: 181)
#
# Run: 64, exploration: 0.01, score: 130
# Scores: (min: 10, avg: 96.921875, max: 181)
#
# Run: 65, exploration: 0.01, score: 122
# Scores: (min: 10, avg: 97.3076923076923, max: 181)
#
# Run: 66, exploration: 0.01, score: 135
# Scores: (min: 10, avg: 97.87878787878788, max: 181)
#
# Run: 67, exploration: 0.01, score: 132
# Scores: (min: 10, avg: 98.38805970149254, max: 181)
#
# Run: 68, exploration: 0.01, score: 120
# Scores: (min: 10, avg: 98.70588235294117, max: 181)
#
# Run: 69, exploration: 0.01, score: 119
# Scores: (min: 10, avg: 99, max: 181)
#
# Run: 70, exploration: 0.01, score: 142
# Scores: (min: 10, avg: 99.61428571428571, max: 181)
#
# Run: 71, exploration: 0.01, score: 87
# Scores: (min: 10, avg: 99.43661971830986, max: 181)
#
# Run: 72, exploration: 0.01, score: 125
# Scores: (min: 10, avg: 99.79166666666667, max: 181)
#
# Run: 73, exploration: 0.01, score: 118
# Scores: (min: 10, avg: 100.04109589041096, max: 181)
#
# Run: 74, exploration: 0.01, score: 134
# Scores: (min: 10, avg: 100.5, max: 181)
#
# Run: 75, exploration: 0.01, score: 114
# Scores: (min: 10, avg: 100.68, max: 181)
#
# Run: 76, exploration: 0.01, score: 109
# Scores: (min: 10, avg: 100.78947368421052, max: 181)
#
# Run: 77, exploration: 0.01, score: 28
# Scores: (min: 10, avg: 99.84415584415585, max: 181)
#
# Run: 78, exploration: 0.01, score: 145
# Scores: (min: 10, avg: 100.42307692307692, max: 181)
#
# Run: 79, exploration: 0.01, score: 124
# Scores: (min: 10, avg: 100.72151898734177, max: 181)
#
# Run: 80, exploration: 0.01, score: 126
# Scores: (min: 10, avg: 101.0375, max: 181)
#
# Run: 81, exploration: 0.01, score: 133
# Scores: (min: 10, avg: 101.4320987654321, max: 181)
#
# Run: 82, exploration: 0.01, score: 105
# Scores: (min: 10, avg: 101.47560975609755, max: 181)
#
# Run: 83, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 100.39759036144578, max: 181)
#
# Run: 84, exploration: 0.01, score: 100
# Scores: (min: 10, avg: 100.39285714285714, max: 181)
#
# Run: 85, exploration: 0.01, score: 85
# Scores: (min: 10, avg: 100.21176470588236, max: 181)
#
# Run: 86, exploration: 0.01, score: 171
# Scores: (min: 10, avg: 101.03488372093024, max: 181)
#
# Run: 87, exploration: 0.01, score: 156
# Scores: (min: 10, avg: 101.66666666666667, max: 181)
#
# Run: 88, exploration: 0.01, score: 182
# Scores: (min: 10, avg: 102.57954545454545, max: 182)
#
# Run: 89, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 101.53932584269663, max: 182)
#
# Run: 90, exploration: 0.01, score: 293
# Scores: (min: 10, avg: 103.66666666666667, max: 293)
# Run: 91, exploration: 0.01, score: 108
# Scores: (min: 10, avg: 103.71428571428571, max: 293)
#
# Run: 92, exploration: 0.01, score: 166
# Scores: (min: 10, avg: 104.3913043478261, max: 293)
#
# Run: 93, exploration: 0.01, score: 139
# Scores: (min: 10, avg: 104.76344086021506, max: 293)
#
# Run: 94, exploration: 0.01, score: 164
# Scores: (min: 10, avg: 105.3936170212766, max: 293)
#
# Run: 95, exploration: 0.01, score: 176
# Scores: (min: 10, avg: 106.13684210526316, max: 293)
#
# Run: 96, exploration: 0.01, score: 114
# Scores: (min: 10, avg: 106.21875, max: 293)
#
# Run: 97, exploration: 0.01, score: 127
# Scores: (min: 10, avg: 106.43298969072166, max: 293)
#
# Run: 98, exploration: 0.01, score: 260
# Scores: (min: 10, avg: 108, max: 293)
#
# Run: 99, exploration: 0.01, score: 127
# Scores: (min: 10, avg: 108.1919191919192, max: 293)
#
# Run: 100, exploration: 0.01, score: 118
# Scores: (min: 10, avg: 108.29, max: 293)
#
# Run: 101, exploration: 0.01, score: 45
# Scores: (min: 10, avg: 108.58, max: 293)
#
# Run: 102, exploration: 0.01, score: 254
# Scores: (min: 10, avg: 110.96, max: 293)
#
# Run: 103, exploration: 0.01, score: 209
# Scores: (min: 10, avg: 112.95, max: 293)
#
# Run: 104, exploration: 0.01, score: 135
# Scores: (min: 10, avg: 114.2, max: 293)
#
# Run: 105, exploration: 0.01, score: 131
# Scores: (min: 10, avg: 115.37, max: 293)
#
# Run: 106, exploration: 0.01, score: 127
# Scores: (min: 10, avg: 116.45, max: 293)
#
# Run: 107, exploration: 0.01, score: 121
# Scores: (min: 10, avg: 117.29, max: 293)
#
# Run: 108, exploration: 0.01, score: 150
# Scores: (min: 10, avg: 118.62, max: 293)
#
# Run: 109, exploration: 0.01, score: 201
# Scores: (min: 10, avg: 120.48, max: 293)
#
# Run: 110, exploration: 0.01, score: 163
# Scores: (min: 10, avg: 121.79, max: 293)
#
# Run: 111, exploration: 0.01, score: 133
# Scores: (min: 10, avg: 122.41, max: 293)
#
# Run: 112, exploration: 0.01, score: 167
# Scores: (min: 10, avg: 123.72, max: 293)
#
# Run: 113, exploration: 0.01, score: 128
# Scores: (min: 10, avg: 124.58, max: 293)
#
# Run: 114, exploration: 0.01, score: 283
# Scores: (min: 10, avg: 126.56, max: 293)
#
# Run: 115, exploration: 0.01, score: 140
# Scores: (min: 10, avg: 126.9, max: 293)
#
# Run: 116, exploration: 0.01, score: 136
# Scores: (min: 10, avg: 126.94, max: 293)
#
# Run: 117, exploration: 0.01, score: 107
# Scores: (min: 10, avg: 127.25, max: 293)
#
# Run: 118, exploration: 0.01, score: 162
# Scores: (min: 10, avg: 127.93, max: 293)
#
# Run: 119, exploration: 0.01, score: 114
# Scores: (min: 10, avg: 128.25, max: 293)
#
# Run: 120, exploration: 0.01, score: 163
# Scores: (min: 10, avg: 128.96, max: 293)
#
# Run: 121, exploration: 0.01, score: 189
# Scores: (min: 10, avg: 129.84, max: 293)
#
# Run: 122, exploration: 0.01, score: 125
# Scores: (min: 10, avg: 130.06, max: 293)
#
# Run: 123, exploration: 0.01, score: 112
# Scores: (min: 10, avg: 129.77, max: 293)
#
# Run: 124, exploration: 0.01, score: 187
# Scores: (min: 10, avg: 130.37, max: 293)
#
# Run: 125, exploration: 0.01, score: 106
# Scores: (min: 10, avg: 129.62, max: 293)
#
# Run: 126, exploration: 0.01, score: 118
# Scores: (min: 10, avg: 129.34, max: 293)
#
# Run: 127, exploration: 0.01, score: 267
# Scores: (min: 10, avg: 130.77, max: 293)
#
# Run: 128, exploration: 0.01, score: 115
# Scores: (min: 10, avg: 130.75, max: 293)
#
# Run: 129, exploration: 0.01, score: 116
# Scores: (min: 10, avg: 130.41, max: 293)
#
# Run: 130, exploration: 0.01, score: 95
# Scores: (min: 10, avg: 130.04, max: 293)
#
# Run: 131, exploration: 0.01, score: 116
# Scores: (min: 10, avg: 130.15, max: 293)
#
# Run: 132, exploration: 0.01, score: 134
# Scores: (min: 10, avg: 130.3, max: 293)
#
# Run: 133, exploration: 0.01, score: 273
# Scores: (min: 10, avg: 131.95, max: 293)
#
# Run: 134, exploration: 0.01, score: 154
# Scores: (min: 10, avg: 132.08, max: 293)
#
# Run: 135, exploration: 0.01, score: 127
# Scores: (min: 10, avg: 132.25, max: 293)
#
# Run: 136, exploration: 0.01, score: 172
# Scores: (min: 10, avg: 132.48, max: 293)
#
# Run: 137, exploration: 0.01, score: 118
# Scores: (min: 10, avg: 132.42, max: 293)
#
# Run: 138, exploration: 0.01, score: 136
# Scores: (min: 10, avg: 132.66, max: 293)
#
# Run: 139, exploration: 0.01, score: 72
# Scores: (min: 10, avg: 132.17, max: 293)
#
# Run: 140, exploration: 0.01, score: 49
# Scores: (min: 10, avg: 131.51, max: 293)
#
# Run: 141, exploration: 0.01, score: 168
# Scores: (min: 10, avg: 131.93, max: 293)
#
# Run: 142, exploration: 0.01, score: 212
# Scores: (min: 10, avg: 132.69, max: 293)
#
# Run: 143, exploration: 0.01, score: 80
# Scores: (min: 10, avg: 132.31, max: 293)
#
# Run: 144, exploration: 0.01, score: 157
# Scores: (min: 10, avg: 132.64, max: 293)
#
# Run: 145, exploration: 0.01, score: 107
# Scores: (min: 10, avg: 132.56, max: 293)
#
# Run: 146, exploration: 0.01, score: 147
# Scores: (min: 10, avg: 132.96, max: 293)
#
# Run: 147, exploration: 0.01, score: 50
# Scores: (min: 10, avg: 133.28, max: 293)
#
# Run: 148, exploration: 0.01, score: 147
# Scores: (min: 10, avg: 134.43, max: 293)
#
# Run: 149, exploration: 0.01, score: 211
# Scores: (min: 10, avg: 135.42, max: 293)
#
# Run: 150, exploration: 0.01, score: 192
# Scores: (min: 10, avg: 136.07, max: 293)
#
# Run: 151, exploration: 0.01, score: 97
# Scores: (min: 10, avg: 135.83, max: 293)
#
# Run: 152, exploration: 0.01, score: 116
# Scores: (min: 10, avg: 135.95, max: 293)
#
# Run: 153, exploration: 0.01, score: 128
# Scores: (min: 10, avg: 136.21, max: 293)
#
# Run: 154, exploration: 0.01, score: 67
# Scores: (min: 10, avg: 135.49, max: 293)
#
# Run: 155, exploration: 0.01, score: 217
# Scores: (min: 10, avg: 136.58, max: 293)
#
# Run: 156, exploration: 0.01, score: 289
# Scores: (min: 10, avg: 138.35, max: 293)
#
# Run: 157, exploration: 0.01, score: 105
# Scores: (min: 10, avg: 138.45, max: 293)
#
# Run: 158, exploration: 0.01, score: 86
# Scores: (min: 10, avg: 138, max: 293)
#
# Run: 159, exploration: 0.01, score: 272
# Scores: (min: 10, avg: 139.5, max: 293)
#
# Run: 160, exploration: 0.01, score: 225
# Scores: (min: 10, avg: 140.11, max: 293)
#
# Run: 161, exploration: 0.01, score: 53
# Scores: (min: 10, avg: 139.61, max: 293)
#
# Run: 162, exploration: 0.01, score: 131
# Scores: (min: 10, avg: 139.65, max: 293)
#
# Run: 163, exploration: 0.01, score: 192
# Scores: (min: 10, avg: 140.55, max: 293)
#
# Run: 164, exploration: 0.01, score: 236
# Scores: (min: 10, avg: 141.61, max: 293)
#
# Run: 165, exploration: 0.01, score: 121
# Scores: (min: 10, avg: 141.6, max: 293)
#
# Run: 166, exploration: 0.01, score: 157
# Scores: (min: 10, avg: 141.82, max: 293)
#
# Run: 167, exploration: 0.01, score: 154
# Scores: (min: 10, avg: 142.04, max: 293)
#
# Run: 168, exploration: 0.01, score: 265
# Scores: (min: 10, avg: 143.49, max: 293)
#
# Run: 169, exploration: 0.01, score: 34
# Scores: (min: 10, avg: 142.64, max: 293)
#
# Run: 170, exploration: 0.01, score: 224
# Scores: (min: 10, avg: 143.46, max: 293)
#
# Run: 171, exploration: 0.01, score: 216
# Scores: (min: 10, avg: 144.75, max: 293)
#
# Run: 172, exploration: 0.01, score: 347
# Scores: (min: 10, avg: 146.97, max: 347)
#
# Run: 173, exploration: 0.01, score: 33
# Scores: (min: 10, avg: 146.12, max: 347)
#
# Run: 174, exploration: 0.01, score: 17
# Scores: (min: 10, avg: 144.95, max: 347)
#
# Run: 175, exploration: 0.01, score: 23
# Scores: (min: 10, avg: 144.04, max: 347)
#
# Run: 176, exploration: 0.01, score: 152
# Scores: (min: 10, avg: 144.47, max: 347)
#
# Run: 177, exploration: 0.01, score: 143
# Scores: (min: 10, avg: 145.62, max: 347)
#
# Run: 178, exploration: 0.01, score: 108
# Scores: (min: 10, avg: 145.25, max: 347)
#
# Run: 179, exploration: 0.01, score: 31
# Scores: (min: 10, avg: 144.32, max: 347)
#
# Run: 180, exploration: 0.01, score: 38
# Scores: (min: 10, avg: 143.44, max: 347)
#
# Run: 181, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 142.22, max: 347)
#
# Run: 182, exploration: 0.01, score: 59
# Scores: (min: 10, avg: 141.76, max: 347)
#
# Run: 183, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 141.75, max: 347)
#
# Run: 184, exploration: 0.01, score: 15
# Scores: (min: 10, avg: 140.9, max: 347)
#
# Run: 185, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 140.16, max: 347)
#
# Run: 186, exploration: 0.01, score: 16
# Scores: (min: 10, avg: 138.61, max: 347)
#
# Run: 187, exploration: 0.01, score: 96
# Scores: (min: 10, avg: 138.01, max: 347)
#
# Run: 188, exploration: 0.01, score: 78
# Scores: (min: 10, avg: 136.97, max: 347)
#
# Run: 189, exploration: 0.01, score: 116
# Scores: (min: 11, avg: 138.03, max: 347)
#
# Run: 190, exploration: 0.01, score: 150
# Scores: (min: 11, avg: 136.6, max: 347)
# Run: 191, exploration: 0.01, score: 131
# Scores: (min: 11, avg: 136.83, max: 347)
#
# Run: 192, exploration: 0.01, score: 143
# Scores: (min: 11, avg: 136.6, max: 347)
#
# Run: 193, exploration: 0.01, score: 202
# Scores: (min: 11, avg: 137.23, max: 347)
#
# Run: 194, exploration: 0.01, score: 99
# Scores: (min: 11, avg: 136.58, max: 347)
#
# Run: 195, exploration: 0.01, score: 89
# Scores: (min: 11, avg: 135.71, max: 347)
#
# Run: 196, exploration: 0.01, score: 147
# Scores: (min: 11, avg: 136.04, max: 347)
#
# Run: 197, exploration: 0.01, score: 217
# Scores: (min: 11, avg: 136.94, max: 347)
#
# Run: 198, exploration: 0.01, score: 162
# Scores: (min: 11, avg: 135.96, max: 347)
#
# Run: 199, exploration: 0.01, score: 217
# Scores: (min: 11, avg: 136.86, max: 347)
#
# Run: 200, exploration: 0.01, score: 109
# Scores: (min: 11, avg: 136.77, max: 347)
#
# Run: 201, exploration: 0.01, score: 127
# Scores: (min: 11, avg: 137.59, max: 347)
#
# Run: 202, exploration: 0.01, score: 103
# Scores: (min: 11, avg: 136.08, max: 347)
#
# Run: 203, exploration: 0.01, score: 57
# Scores: (min: 11, avg: 134.56, max: 347)
#
# Run: 204, exploration: 0.01, score: 16
# Scores: (min: 11, avg: 133.37, max: 347)
#
# Run: 205, exploration: 0.01, score: 69
# Scores: (min: 11, avg: 132.75, max: 347)
#
# Run: 206, exploration: 0.01, score: 48
# Scores: (min: 11, avg: 131.96, max: 347)
#
# Run: 207, exploration: 0.01, score: 122
# Scores: (min: 11, avg: 131.97, max: 347)
#
# Run: 208, exploration: 0.01, score: 116
# Scores: (min: 11, avg: 131.63, max: 347)
#
# Run: 209, exploration: 0.01, score: 104
# Scores: (min: 11, avg: 130.66, max: 347)
#
# Run: 210, exploration: 0.01, score: 155
# Scores: (min: 11, avg: 130.58, max: 347)
#
# Run: 211, exploration: 0.01, score: 188
# Scores: (min: 11, avg: 131.13, max: 347)
#
# Run: 212, exploration: 0.01, score: 102
# Scores: (min: 11, avg: 130.48, max: 347)
#
# Run: 213, exploration: 0.01, score: 135
# Scores: (min: 11, avg: 130.55, max: 347)
#
# Run: 214, exploration: 0.01, score: 247
# Scores: (min: 11, avg: 130.19, max: 347)
#
# Run: 215, exploration: 0.01, score: 194
# Scores: (min: 11, avg: 130.73, max: 347)
#
# Run: 216, exploration: 0.01, score: 201
# Scores: (min: 11, avg: 131.38, max: 347)
#
# Run: 217, exploration: 0.01, score: 283
# Scores: (min: 11, avg: 133.14, max: 347)
#
# Run: 218, exploration: 0.01, score: 115
# Scores: (min: 11, avg: 132.67, max: 347)
#
# Run: 219, exploration: 0.01, score: 216
# Scores: (min: 11, avg: 133.69, max: 347)
#
# Run: 220, exploration: 0.01, score: 117
# Scores: (min: 11, avg: 133.23, max: 347)
#
# Run: 221, exploration: 0.01, score: 67
# Scores: (min: 11, avg: 132.01, max: 347)
#
# Run: 222, exploration: 0.01, score: 141
# Scores: (min: 11, avg: 132.17, max: 347)
#
# Run: 223, exploration: 0.01, score: 85
# Scores: (min: 11, avg: 131.9, max: 347)
#
# Run: 224, exploration: 0.01, score: 113
# Scores: (min: 11, avg: 131.16, max: 347)
#
# Run: 225, exploration: 0.01, score: 98
# Scores: (min: 11, avg: 131.08, max: 347)
#
# Run: 226, exploration: 0.01, score: 92
# Scores: (min: 11, avg: 130.82, max: 347)
#
# Run: 227, exploration: 0.01, score: 112
# Scores: (min: 11, avg: 129.27, max: 347)
#
# Run: 228, exploration: 0.01, score: 132
# Scores: (min: 11, avg: 129.44, max: 347)
#
# Run: 229, exploration: 0.01, score: 84
# Scores: (min: 11, avg: 129.12, max: 347)
#
# Run: 230, exploration: 0.01, score: 28
# Scores: (min: 11, avg: 128.45, max: 347)
#
# Run: 231, exploration: 0.01, score: 119
# Scores: (min: 11, avg: 128.48, max: 347)
#
# Run: 232, exploration: 0.01, score: 179
# Scores: (min: 11, avg: 128.93, max: 347)
#
# Run: 233, exploration: 0.01, score: 22
# Scores: (min: 11, avg: 126.42, max: 347)
#
# Run: 234, exploration: 0.01, score: 21
# Scores: (min: 11, avg: 125.09, max: 347)
#
# Run: 235, exploration: 0.01, score: 20
# Scores: (min: 11, avg: 124.02, max: 347)
#
# Run: 236, exploration: 0.01, score: 20
# Scores: (min: 11, avg: 122.5, max: 347)
#
# Run: 237, exploration: 0.01, score: 13
# Scores: (min: 11, avg: 121.45, max: 347)
#
# Run: 238, exploration: 0.01, score: 12
# Scores: (min: 11, avg: 120.21, max: 347)
#
# Run: 239, exploration: 0.01, score: 15
# Scores: (min: 11, avg: 119.64, max: 347)
#
# Run: 240, exploration: 0.01, score: 15
# Scores: (min: 11, avg: 119.3, max: 347)
#
# Run: 241, exploration: 0.01, score: 14
# Scores: (min: 11, avg: 117.76, max: 347)
#
# Run: 242, exploration: 0.01, score: 14
# Scores: (min: 11, avg: 115.78, max: 347)
#
# Run: 243, exploration: 0.01, score: 16
# Scores: (min: 11, avg: 115.14, max: 347)
#
# Run: 244, exploration: 0.01, score: 11
# Scores: (min: 11, avg: 113.68, max: 347)
#
# Run: 245, exploration: 0.01, score: 354
# Scores: (min: 11, avg: 116.15, max: 354)
#
# Run: 246, exploration: 0.01, score: 61
# Scores: (min: 11, avg: 115.29, max: 354)
#
# Run: 247, exploration: 0.01, score: 42
# Scores: (min: 11, avg: 115.21, max: 354)
#
# Run: 248, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 113.83, max: 354)
#
# Run: 249, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 111.88, max: 354)
#
# Run: 250, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 110.06, max: 354)
#
# Run: 251, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 109.18, max: 354)
#
# Run: 252, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 108.13, max: 354)
#
# Run: 253, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 106.94, max: 354)
#
# Run: 254, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 106.36, max: 354)
#
# Run: 255, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 104.29, max: 354)
#
# Run: 256, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 101.48, max: 354)
#
# Run: 257, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 100.52, max: 354)
#
# Run: 258, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 99.74, max: 354)
#
# Run: 259, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 97.12, max: 354)
#
# Run: 260, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 94.96, max: 354)
#
# Run: 261, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 94.52, max: 354)
#
# Run: 262, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 93.32, max: 354)
#
# Run: 263, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 91.5, max: 354)
#
# Run: 264, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 89.24, max: 354)
#
# Run: 265, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 88.13, max: 354)
#
# Run: 266, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 86.65, max: 354)
#
# Run: 267, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 85.21, max: 354)
#
# Run: 268, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 82.65, max: 354)
#
# Run: 269, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 82.4, max: 354)
#
# Run: 270, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 80.26, max: 354)
#
# Run: 271, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 78.2, max: 354)
#
# Run: 272, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 74.83, max: 354)
#
# Run: 273, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 74.6, max: 354)
#
# Run: 274, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 74.52, max: 354)
#
# Run: 275, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 74.4, max: 354)
#
# Run: 276, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 72.97, max: 354)
#
# Run: 277, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 71.64, max: 354)
#
# Run: 278, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 70.65, max: 354)
#
# Run: 279, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 70.43, max: 354)
#
# Run: 280, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 70.15, max: 354)
#
# Run: 281, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 70.14, max: 354)
#
# Run: 282, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 69.65, max: 354)
#
# Run: 283, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 69.64, max: 354)
#
# Run: 284, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 69.58, max: 354)
#
# Run: 285, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 69.56, max: 354)
#
# Run: 286, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 69.49, max: 354)
#
# Run: 287, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 68.63, max: 354)
#
# Run: 288, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 67.93, max: 354)
#
# Run: 289, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 66.88, max: 354)
#
# Run: 290, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 65.47, max: 354)
#
# Run: 291, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 64.24, max: 354)
#
# Run: 292, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 62.9, max: 354)
#
# Run: 293, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 60.98, max: 354)
# Run: 294, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 60.09, max: 354)
#
# Run: 295, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 59.3, max: 354)
#
# Run: 296, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 57.93, max: 354)
#
# Run: 297, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 55.86, max: 354)
#
# Run: 298, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 54.33, max: 354)
#
# Run: 299, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 52.26, max: 354)
#
# Run: 300, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 51.26, max: 354)
#
# Run: 301, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 50.09, max: 354)
#
# Run: 302, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 49.16, max: 354)
#
# Run: 303, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 48.68, max: 354)
#
# Run: 304, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 48.62, max: 354)
#
# Run: 305, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 48.03, max: 354)
#
# Run: 306, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 47.65, max: 354)
#
# Run: 307, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 46.53, max: 354)
#
# Run: 308, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 45.47, max: 354)
#
# Run: 309, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 44.52, max: 354)
#
# Run: 310, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 43.08, max: 354)
#
# Run: 311, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 41.3, max: 354)
#
# Run: 312, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 40.37, max: 354)
#
# Run: 313, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 39.1, max: 354)
#
# Run: 314, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 36.73, max: 354)
#
# Run: 315, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 34.89, max: 354)
#
# Run: 316, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 32.98, max: 354)
#
# Run: 317, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.24, max: 354)
#
# Run: 318, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 29.18, max: 354)
#
# Run: 319, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.12, max: 354)
#
# Run: 320, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 26.04, max: 354)
#
# Run: 321, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 25.46, max: 354)
#
# Run: 322, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 24.13, max: 354)
#
# Run: 323, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 23.37, max: 354)
#
# Run: 324, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 22.33, max: 354)
#
# Run: 325, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 21.44, max: 354)
#
# Run: 326, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 20.61, max: 354)
#
# Run: 327, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 19.57, max: 354)
#
# Run: 328, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.35, max: 354)
#
# Run: 329, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.61, max: 354)
#
# Run: 330, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17.42, max: 354)
#
# Run: 331, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.32, max: 354)
#
# Run: 332, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.63, max: 354)
#
# Run: 333, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.51, max: 354)
#
# Run: 334, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.4, max: 354)
#
# Run: 335, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.3, max: 354)
#
# Run: 336, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.2, max: 354)
#
# Run: 337, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.18, max: 354)
#
# Run: 338, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.15, max: 354)
#
# Run: 339, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.11, max: 354)
#
# Run: 340, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.05, max: 354)
#
# Run: 341, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14, max: 354)
#
# Run: 342, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.97, max: 354)
#
# Run: 343, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.91, max: 354)
#
# Run: 344, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.9, max: 354)
#
# Run: 345, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.46, max: 61)
#
# Run: 346, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 9.98, max: 42)
#
# Run: 347, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 9.7, max: 16)
#
# Run: 348, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 9.77, max: 16)
#
# Run: 349, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 10.03, max: 42)
#
# Run: 350, exploration: 0.01, score: 110
# Scores: (min: 8, avg: 11.03, max: 110)
#
# Run: 351, exploration: 0.01, score: 128
# Scores: (min: 8, avg: 12.22, max: 128)
#
# Run: 352, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 12.45, max: 128)
#
# Run: 353, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 12.64, max: 128)
#
# Run: 354, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 12.72, max: 128)
#
# Run: 355, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 12.77, max: 128)
#
# Run: 356, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 12.87, max: 128)
#
# Run: 357, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 12.93, max: 128)
#
# Run: 358, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 13.11, max: 128)
#
# Run: 359, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 13.26, max: 128)
#
# Run: 360, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 13.39, max: 128)
#
# Run: 361, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 13.79, max: 128)
#
# Run: 362, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 14.08, max: 128)
#
# Run: 363, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 14.33, max: 128)
#
# Run: 364, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 14.71, max: 128)
#
# Run: 365, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 15.08, max: 128)
#
# Run: 366, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 15.5, max: 128)
#
# Run: 367, exploration: 0.01, score: 85
# Scores: (min: 8, avg: 16.25, max: 128)
#
# Run: 368, exploration: 0.01, score: 82
# Scores: (min: 8, avg: 16.98, max: 128)
#
# Run: 369, exploration: 0.01, score: 109
# Scores: (min: 8, avg: 17.98, max: 128)
#
# Run: 370, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 18.25, max: 128)
#
# Run: 371, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.25, max: 128)
#
# Run: 372, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 18.23, max: 128)
#
# Run: 373, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.23, max: 128)
#
# Run: 374, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 18.23, max: 128)
#
# Run: 375, exploration: 0.01, score: 261
# Scores: (min: 8, avg: 20.73, max: 261)
#
# Run: 376, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 21.15, max: 261)
#
# Run: 377, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 21.58, max: 261)
#
# Run: 378, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 21.59, max: 261)
#
# Run: 379, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 21.63, max: 261)
#
# Run: 380, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 21.62, max: 261)
#
# Run: 381, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 21.61, max: 261)
#
# Run: 382, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 21.59, max: 261)
#
# Run: 383, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 22.05, max: 261)
#
# Run: 384, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 22.05, max: 261)
#
# Run: 385, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 22.05, max: 261)
#
# Run: 386, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 22.07, max: 261)
#
# Run: 387, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 22.08, max: 261)
#
# Run: 388, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 22.1, max: 261)
#
# Run: 389, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 22.08, max: 261)
#
# Run: 390, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 22.08, max: 261)
#
# Run: 391, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 22.09, max: 261)
#
# Run: 392, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 22.09, max: 261)
#
# Run: 393, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 22.07, max: 261)
#
# Run: 394, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 22.07, max: 261)
#
# Run: 395, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 22.15, max: 261)
#
# Run: 396, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 22.14, max: 261)
#
# Run: 397, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 22.14, max: 261)
#
# Run: 398, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 22.15, max: 261)
# Run: 399, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 22.14, max: 261)
#
# Run: 400, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 22.14, max: 261)
#
# Run: 401, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 22.15, max: 261)
#
# Run: 402, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 22.15, max: 261)
#
# Run: 403, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 22.16, max: 261)
#
# Run: 404, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 22.14, max: 261)
#
# Run: 405, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 22.14, max: 261)
#
# Run: 406, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 22.13, max: 261)
#
# Run: 407, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 22.12, max: 261)
#
# Run: 408, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 22.12, max: 261)
#
# Run: 409, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 22.12, max: 261)
#
# Run: 410, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 22.1, max: 261)
#
# Run: 411, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 22.09, max: 261)
#
# Run: 412, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 22.11, max: 261)
#
# Run: 413, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 22.13, max: 261)
#
# Run: 414, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 22.13, max: 261)
#
# Run: 415, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 22.12, max: 261)
#
# Run: 416, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 22.51, max: 261)
#
# Run: 417, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 22.6, max: 261)
#
# Run: 418, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 22.86, max: 261)
#
# Run: 419, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 23, max: 261)
#
# Run: 420, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 23.01, max: 261)
#
# Run: 421, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 23.23, max: 261)
#
# Run: 422, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 23.46, max: 261)
#
# Run: 423, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 23.72, max: 261)
#
# Run: 424, exploration: 0.01, score: 142
# Scores: (min: 8, avg: 25.05, max: 261)
#
# Run: 425, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 25.04, max: 261)
#
# Run: 426, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 25.17, max: 261)
#
# Run: 427, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 25.19, max: 261)
#
# Run: 428, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 25.47, max: 261)
#
# Run: 429, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 25.51, max: 261)
#
# Run: 430, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 25.51, max: 261)
#
# Run: 431, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 25.65, max: 261)
#
# Run: 432, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 25.64, max: 261)
#
# Run: 433, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 25.63, max: 261)
#
# Run: 434, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 25.61, max: 261)
#
# Run: 435, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 25.59, max: 261)
#
# Run: 436, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 25.59, max: 261)
#
# Run: 437, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 25.56, max: 261)
#
# Run: 438, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 25.56, max: 261)
#
# Run: 439, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 25.54, max: 261)
#
# Run: 440, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 25.55, max: 261)
#
# Run: 441, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 25.56, max: 261)
#
# Run: 442, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 25.56, max: 261)
#
# Run: 443, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 25.55, max: 261)
#
# Run: 444, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 25.57, max: 261)
#
# Run: 445, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 25.57, max: 261)
#
# Run: 446, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 25.53, max: 261)
#
# Run: 447, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 25.51, max: 261)
#
# Run: 448, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 25.62, max: 261)
#
# Run: 449, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 25.3, max: 261)
#
# Run: 450, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 24.29, max: 261)
#
# Run: 451, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 23.1, max: 261)
#
# Run: 452, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 22.91, max: 261)
#
# Run: 453, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 22.73, max: 261)
#
# Run: 454, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 22.66, max: 261)
#
# Run: 455, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 22.61, max: 261)
#
# Run: 456, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 22.51, max: 261)
#
# Run: 457, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 22.47, max: 261)
#
# Run: 458, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 22.32, max: 261)
#
# Run: 459, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 22.16, max: 261)
#
# Run: 460, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 22.06, max: 261)
#
# Run: 461, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 21.65, max: 261)
#
# Run: 462, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 21.34, max: 261)
#
# Run: 463, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 21.08, max: 261)
#
# Run: 464, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 20.7, max: 261)
#
# Run: 465, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 20.33, max: 261)
#
# Run: 466, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 19.92, max: 261)
#
# Run: 467, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 19.17, max: 261)
#
# Run: 468, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 18.44, max: 261)
#
# Run: 469, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17.44, max: 261)
#
# Run: 470, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.17, max: 261)
#
# Run: 471, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.17, max: 261)
#
# Run: 472, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.19, max: 261)
#
# Run: 473, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17.18, max: 261)
#
# Run: 474, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17.18, max: 261)
#
# Run: 475, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.67, max: 142)
#
# Run: 476, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 14.28, max: 142)
#
# Run: 477, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.84, max: 142)
#
# Run: 478, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 13.96, max: 142)
#
# Run: 479, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 14.03, max: 142)
#
# Run: 480, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.03, max: 142)
#
# Run: 481, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 14.2, max: 142)
#
# Run: 482, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.21, max: 142)
#
# Run: 483, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.74, max: 142)
#
# Run: 484, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.74, max: 142)
#
# Run: 485, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 13.82, max: 142)
#
# Run: 486, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 13.91, max: 142)
#
# Run: 487, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.91, max: 142)
#
# Run: 488, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.9, max: 142)
#
# Run: 489, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.9, max: 142)
#
# Run: 490, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 14.05, max: 142)
#
# Run: 491, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.05, max: 142)
#
# Run: 492, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.05, max: 142)
#
# Run: 493, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.07, max: 142)
#
# Run: 494, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.07, max: 142)
#
# Run: 495, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.98, max: 142)
#
# Run: 496, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.97, max: 142)
#
# Run: 497, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 13.97, max: 142)
#
# Run: 498, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 14.02, max: 142)
#
# Run: 499, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 14.08, max: 142)
#
# Run: 500, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 14.17, max: 142)
#
# Run: 501, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.17, max: 142)
#
# Run: 502, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.18, max: 142)
#
# Run: 503, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.17, max: 142)
# Run: 504, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 14.31, max: 142)
#
# Run: 505, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 14.29, max: 142)
#
# Run: 506, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.3, max: 142)
#
# Run: 507, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.3, max: 142)
#
# Run: 508, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 14.34, max: 142)
#
# Run: 509, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 14.4, max: 142)
#
# Run: 510, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.41, max: 142)
#
# Run: 511, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.41, max: 142)
#
# Run: 512, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 14.56, max: 142)
#
# Run: 513, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 14.61, max: 142)
#
# Run: 514, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 14.72, max: 142)
#
# Run: 515, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 14.78, max: 142)
#
# Run: 516, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.4, max: 142)
#
# Run: 517, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.33, max: 142)
#
# Run: 518, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.08, max: 142)
#
# Run: 519, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 13.95, max: 142)
#
# Run: 520, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 14.11, max: 142)
#
# Run: 521, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.89, max: 142)
#
# Run: 522, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 13.81, max: 142)
#
# Run: 523, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 13.59, max: 142)
#
# Run: 524, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.27, max: 38)
#
# Run: 525, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.28, max: 38)
#
# Run: 526, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.16, max: 38)
#
# Run: 527, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.15, max: 38)
#
# Run: 528, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.89, max: 27)
#
# Run: 529, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.83, max: 27)
#
# Run: 530, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 11.94, max: 27)
#
# Run: 531, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 11.85, max: 27)
#
# Run: 532, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.88, max: 27)
#
# Run: 533, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.89, max: 27)
#
# Run: 534, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.94, max: 27)
#
# Run: 535, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.98, max: 27)
#
# Run: 536, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 12.01, max: 27)
#
# Run: 537, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 12.15, max: 27)
#
# Run: 538, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.14, max: 27)
#
# Run: 539, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.13, max: 27)
#
# Run: 540, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.12, max: 27)
#
# Run: 541, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.12, max: 27)
#
# Run: 542, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 12.21, max: 27)
#
# Run: 543, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.21, max: 27)
#
# Run: 544, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.17, max: 27)
#
# Run: 545, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.17, max: 27)
#
# Run: 546, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.19, max: 27)
#
# Run: 547, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 12.61, max: 54)
#
# Run: 548, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.42, max: 54)
#
# Run: 549, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 12.63, max: 54)
#
# Run: 550, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.65, max: 54)
#
# Run: 551, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.65, max: 54)
#
# Run: 552, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.6, max: 54)
#
# Run: 553, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 12.7, max: 54)
#
# Run: 554, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.7, max: 54)
#
# Run: 555, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.7, max: 54)
#
# Run: 556, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.71, max: 54)
#
# Run: 557, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.71, max: 54)
#
# Run: 558, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 13.09, max: 54)
#
# Run: 559, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 13.13, max: 54)
#
# Run: 560, exploration: 0.01, score: 71
# Scores: (min: 8, avg: 13.72, max: 71)
#
# Run: 561, exploration: 0.01, score: 59
# Scores: (min: 8, avg: 14.23, max: 71)
#
# Run: 562, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 14.32, max: 71)
#
# Run: 563, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 14.43, max: 71)
#
# Run: 564, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 14.89, max: 71)
#
# Run: 565, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 15.09, max: 71)
#
# Run: 566, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.08, max: 71)
#
# Run: 567, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.08, max: 71)
#
# Run: 568, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.08, max: 71)
#
# Run: 569, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 15.22, max: 71)
#
# Run: 570, exploration: 0.01, score: 97
# Scores: (min: 8, avg: 16.09, max: 97)
#
# Run: 571, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 16.1, max: 97)
#
# Run: 572, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.09, max: 97)
#
# Run: 573, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 16.12, max: 97)
#
# Run: 574, exploration: 0.01, score: 72
# Scores: (min: 8, avg: 16.75, max: 97)
#
# Run: 575, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 17.11, max: 97)
#
# Run: 576, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 17.16, max: 97)
#
# Run: 577, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 17.19, max: 97)
#
# Run: 578, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 17.25, max: 97)
#
# Run: 579, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 17.46, max: 97)
#
# Run: 580, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 17.48, max: 97)
#
# Run: 581, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 17.7, max: 97)
#
# Run: 582, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 17.92, max: 97)
#
# Run: 583, exploration: 0.01, score: 75
# Scores: (min: 8, avg: 18.58, max: 97)
#
# Run: 584, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 18.78, max: 97)
#
# Run: 585, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 18.82, max: 97)
#
# Run: 586, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 18.76, max: 97)
#
# Run: 587, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 19.18, max: 97)
#
# Run: 588, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 19.69, max: 97)
#
# Run: 589, exploration: 0.01, score: 66
# Scores: (min: 8, avg: 20.26, max: 97)
#
# Run: 590, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 20.41, max: 97)
#
# Run: 591, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 20.41, max: 97)
#
# Run: 592, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 20.79, max: 97)
#
# Run: 593, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 20.79, max: 97)
#
# Run: 594, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 20.78, max: 97)
#
# Run: 595, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 20.78, max: 97)
#
# Run: 596, exploration: 0.01, score: 117
# Scores: (min: 8, avg: 21.87, max: 117)
#
# Run: 597, exploration: 0.01, score: 81
# Scores: (min: 8, avg: 22.58, max: 117)
#
# Run: 598, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 22.96, max: 117)
#
# Run: 599, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 23, max: 117)
#
# Run: 600, exploration: 0.01, score: 80
# Scores: (min: 8, avg: 23.62, max: 117)
#
# Run: 601, exploration: 0.01, score: 82
# Scores: (min: 8, avg: 24.33, max: 117)
#
# Run: 602, exploration: 0.01, score: 69
# Scores: (min: 8, avg: 24.91, max: 117)
#
# Run: 603, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 25.37, max: 117)
#
# Run: 604, exploration: 0.01, score: 61
# Scores: (min: 8, avg: 25.76, max: 117)
#
# Run: 605, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 25.82, max: 117)
#
# Run: 606, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 26.08, max: 117)
#
# Run: 607, exploration: 0.01, score: 69
# Scores: (min: 8, avg: 26.68, max: 117)
#
# Run: 608, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 27, max: 117)
#
# Run: 609, exploration: 0.01, score: 67
# Scores: (min: 8, avg: 27.52, max: 117)
# Run: 610, exploration: 0.01, score: 63
# Scores: (min: 8, avg: 28.05, max: 117)
#
# Run: 611, exploration: 0.01, score: 66
# Scores: (min: 8, avg: 28.62, max: 117)
#
# Run: 612, exploration: 0.01, score: 79
# Scores: (min: 8, avg: 29.15, max: 117)
#
# Run: 613, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 29.2, max: 117)
#
# Run: 614, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 29.11, max: 117)
#
# Run: 615, exploration: 0.01, score: 74
# Scores: (min: 8, avg: 29.7, max: 117)
#
# Run: 616, exploration: 0.01, score: 117
# Scores: (min: 8, avg: 30.76, max: 117)
#
# Run: 617, exploration: 0.01, score: 82
# Scores: (min: 8, avg: 31.47, max: 117)
#
# Run: 618, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 31.73, max: 117)
#
# Run: 619, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 31.73, max: 117)
#
# Run: 620, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 31.98, max: 117)
#
# Run: 621, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 32.09, max: 117)
#
# Run: 622, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 31.96, max: 117)
#
# Run: 623, exploration: 0.01, score: 67
# Scores: (min: 8, avg: 32.5, max: 117)
#
# Run: 624, exploration: 0.01, score: 75
# Scores: (min: 8, avg: 33.15, max: 117)
#
# Run: 625, exploration: 0.01, score: 123
# Scores: (min: 8, avg: 34.29, max: 123)
#
# Run: 626, exploration: 0.01, score: 70
# Scores: (min: 8, avg: 34.89, max: 123)
#
# Run: 627, exploration: 0.01, score: 80
# Scores: (min: 8, avg: 35.6, max: 123)
#
# Run: 628, exploration: 0.01, score: 90
# Scores: (min: 8, avg: 36.38, max: 123)
#
# Run: 629, exploration: 0.01, score: 69
# Scores: (min: 8, avg: 36.99, max: 123)
#
# Run: 630, exploration: 0.01, score: 108
# Scores: (min: 8, avg: 37.87, max: 123)
#
# Run: 631, exploration: 0.01, score: 68
# Scores: (min: 8, avg: 38.41, max: 123)
#
# Run: 632, exploration: 0.01, score: 95
# Scores: (min: 8, avg: 39.24, max: 123)
#
# Run: 633, exploration: 0.01, score: 103
# Scores: (min: 8, avg: 40.17, max: 123)
#
# Run: 634, exploration: 0.01, score: 88
# Scores: (min: 8, avg: 40.92, max: 123)
#
# Run: 635, exploration: 0.01, score: 86
# Scores: (min: 8, avg: 41.66, max: 123)
#
# Run: 636, exploration: 0.01, score: 149
# Scores: (min: 8, avg: 43.02, max: 149)
#
# Run: 637, exploration: 0.01, score: 84
# Scores: (min: 8, avg: 43.64, max: 149)
#
# Run: 638, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 44.06, max: 149)
#
# Run: 639, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 44.1, max: 149)
#
# Run: 640, exploration: 0.01, score: 117
# Scores: (min: 8, avg: 45.18, max: 149)
#
# Run: 641, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 45.29, max: 149)
#
# Run: 642, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 45.19, max: 149)
#
# Run: 643, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 45.23, max: 149)
#
# Run: 644, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 45.31, max: 149)
#
# Run: 645, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 45.38, max: 149)
#
# Run: 646, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 45.37, max: 149)
#
# Run: 647, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 45, max: 149)
#
# Run: 648, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 45.07, max: 149)
#
# Run: 649, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 44.86, max: 149)
#
# Run: 650, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 44.88, max: 149)
#
# Run: 651, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 44.91, max: 149)
#
# Run: 652, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 44.9, max: 149)
#
# Run: 653, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 44.88, max: 149)
#
# Run: 654, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 44.9, max: 149)
#
# Run: 655, exploration: 0.01, score: 17
# Scores: (min: 9, avg: 44.97, max: 149)
#
# Run: 656, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 45, max: 149)
#
# Run: 657, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 45, max: 149)
#
# Run: 658, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 44.71, max: 149)
#
# Run: 659, exploration: 0.01, score: 26
# Scores: (min: 9, avg: 44.84, max: 149)
#
# Run: 660, exploration: 0.01, score: 61
# Scores: (min: 9, avg: 44.74, max: 149)
#
# Run: 661, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 44.27, max: 149)
#
# Run: 662, exploration: 0.01, score: 88
# Scores: (min: 9, avg: 44.97, max: 149)
#
# Run: 663, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 44.9, max: 149)
#
# Run: 664, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 44.43, max: 149)
#
# Run: 665, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 44.23, max: 149)
#
# Run: 666, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 44.24, max: 149)
#
# Run: 667, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 44.23, max: 149)
#
# Run: 668, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 44.26, max: 149)
#
# Run: 669, exploration: 0.01, score: 60
# Scores: (min: 9, avg: 44.63, max: 149)
#
# Run: 670, exploration: 0.01, score: 258
# Scores: (min: 9, avg: 46.24, max: 258)
#
# Run: 671, exploration: 0.01, score: 209
# Scores: (min: 9, avg: 48.22, max: 258)
#
# Run: 672, exploration: 0.01, score: 28
# Scores: (min: 9, avg: 48.41, max: 258)
#
# Run: 673, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 48.4, max: 258)
#
# Run: 674, exploration: 0.01, score: 29
# Scores: (min: 9, avg: 47.97, max: 258)
#
# Run: 675, exploration: 0.01, score: 31
# Scores: (min: 9, avg: 47.82, max: 258)
#
# Run: 676, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 47.78, max: 258)
#
# Run: 677, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 47.8, max: 258)
#
# Run: 678, exploration: 0.01, score: 17
# Scores: (min: 9, avg: 47.69, max: 258)
#
# Run: 679, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 47.49, max: 258)
#
# Run: 680, exploration: 0.01, score: 124
# Scores: (min: 9, avg: 48.62, max: 258)
#
# Run: 681, exploration: 0.01, score: 27
# Scores: (min: 9, avg: 48.41, max: 258)
#
# Run: 682, exploration: 0.01, score: 71
# Scores: (min: 9, avg: 48.81, max: 258)
#
# Run: 683, exploration: 0.01, score: 36
# Scores: (min: 9, avg: 48.42, max: 258)
#
# Run: 684, exploration: 0.01, score: 48
# Scores: (min: 9, avg: 48.61, max: 258)
#
# Run: 685, exploration: 0.01, score: 31
# Scores: (min: 9, avg: 48.71, max: 258)
#
# Run: 686, exploration: 0.01, score: 25
# Scores: (min: 9, avg: 48.82, max: 258)
#
# Run: 687, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 48.49, max: 258)
#
# Run: 688, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 48.05, max: 258)
#
# Run: 689, exploration: 0.01, score: 27
# Scores: (min: 9, avg: 47.66, max: 258)
#
# Run: 690, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 47.49, max: 258)
#
# Run: 691, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 47.61, max: 258)
#
# Run: 692, exploration: 0.01, score: 23
# Scores: (min: 9, avg: 47.37, max: 258)
#
# Run: 693, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 47.39, max: 258)
#
# Run: 694, exploration: 0.01, score: 27
# Scores: (min: 9, avg: 47.57, max: 258)
#
# Run: 695, exploration: 0.01, score: 40
# Scores: (min: 9, avg: 47.88, max: 258)
#
# Run: 696, exploration: 0.01, score: 43
# Scores: (min: 9, avg: 47.14, max: 258)
#
# Run: 697, exploration: 0.01, score: 49
# Scores: (min: 9, avg: 46.82, max: 258)
#
# Run: 698, exploration: 0.01, score: 103
# Scores: (min: 9, avg: 47.32, max: 258)
#
# Run: 699, exploration: 0.01, score: 198
# Scores: (min: 9, avg: 49.11, max: 258)
#
# Run: 700, exploration: 0.01, score: 113
# Scores: (min: 9, avg: 49.44, max: 258)
#
# Run: 701, exploration: 0.01, score: 215
# Scores: (min: 9, avg: 50.77, max: 258)
#
# Run: 702, exploration: 0.01, score: 339
# Scores: (min: 9, avg: 53.47, max: 339)
#
# Run: 703, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 57.92, max: 500)
#
# Run: 704, exploration: 0.01, score: 304
# Scores: (min: 9, avg: 60.35, max: 500)
#
# Run: 705, exploration: 0.01, score: 78
# Scores: (min: 9, avg: 60.99, max: 500)
#
# Run: 706, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 65.63, max: 500)
#
# Run: 707, exploration: 0.01, score: 321
# Scores: (min: 9, avg: 68.15, max: 500)
#
# Run: 708, exploration: 0.01, score: 169
# Scores: (min: 9, avg: 69.38, max: 500)
#
# Run: 709, exploration: 0.01, score: 272
# Scores: (min: 9, avg: 71.43, max: 500)
#
# Run: 710, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 75.8, max: 500)
#
# Run: 711, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 80.14, max: 500)
#
# Run: 712, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 84.35, max: 500)
#
# Run: 713, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 89.15, max: 500)
# Run: 714, exploration: 0.01, score: 262
# Scores: (min: 9, avg: 91.65, max: 500)
#
# Run: 715, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 95.91, max: 500)
#
# Run: 716, exploration: 0.01, score: 229
# Scores: (min: 9, avg: 97.03, max: 500)
#
# Run: 717, exploration: 0.01, score: 302
# Scores: (min: 9, avg: 99.23, max: 500)
#
# Run: 718, exploration: 0.01, score: 276
# Scores: (min: 9, avg: 101.63, max: 500)
#
# Run: 719, exploration: 0.01, score: 315
# Scores: (min: 9, avg: 104.67, max: 500)
#
# Run: 720, exploration: 0.01, score: 344
# Scores: (min: 9, avg: 107.6, max: 500)
#
# Run: 721, exploration: 0.01, score: 317
# Scores: (min: 9, avg: 110.57, max: 500)
#
# Run: 722, exploration: 0.01, score: 354
# Scores: (min: 9, avg: 114.01, max: 500)
#
# Run: 723, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 118.34, max: 500)
#
# Run: 724, exploration: 0.01, score: 328
# Scores: (min: 9, avg: 120.87, max: 500)
#
# Run: 725, exploration: 0.01, score: 471
# Scores: (min: 9, avg: 124.35, max: 500)
#
# Run: 726, exploration: 0.01, score: 345
# Scores: (min: 9, avg: 127.1, max: 500)
#
# Run: 727, exploration: 0.01, score: 187
# Scores: (min: 9, avg: 128.17, max: 500)
#
# Run: 728, exploration: 0.01, score: 462
# Scores: (min: 9, avg: 131.89, max: 500)
#
# Run: 729, exploration: 0.01, score: 252
# Scores: (min: 9, avg: 133.72, max: 500)
#
# Run: 730, exploration: 0.01, score: 269
# Scores: (min: 9, avg: 135.33, max: 500)
#
# Run: 731, exploration: 0.01, score: 457
# Scores: (min: 9, avg: 139.22, max: 500)
#
# Run: 732, exploration: 0.01, score: 443
# Scores: (min: 9, avg: 142.7, max: 500)
#
# Run: 733, exploration: 0.01, score: 223
# Scores: (min: 9, avg: 143.9, max: 500)
#
# Run: 734, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 148.02, max: 500)
#
# Run: 735, exploration: 0.01, score: 245
# Scores: (min: 9, avg: 149.61, max: 500)
#
# Run: 736, exploration: 0.01, score: 268
# Scores: (min: 9, avg: 150.8, max: 500)
#
# Run: 737, exploration: 0.01, score: 285
# Scores: (min: 9, avg: 152.81, max: 500)
#
# Run: 738, exploration: 0.01, score: 267
# Scores: (min: 9, avg: 154.98, max: 500)
#
# Run: 739, exploration: 0.01, score: 234
# Scores: (min: 9, avg: 157.2, max: 500)
#
# Run: 740, exploration: 0.01, score: 204
# Scores: (min: 9, avg: 158.07, max: 500)
#
# Run: 741, exploration: 0.01, score: 257
# Scores: (min: 9, avg: 160.43, max: 500)
#
# Run: 742, exploration: 0.01, score: 203
# Scores: (min: 9, avg: 162.36, max: 500)
#
# Run: 743, exploration: 0.01, score: 388
# Scores: (min: 9, avg: 166.11, max: 500)
#
# Run: 744, exploration: 0.01, score: 308
# Scores: (min: 9, avg: 169.03, max: 500)
#
# Run: 745, exploration: 0.01, score: 237
# Scores: (min: 9, avg: 171.23, max: 500)
#
# Run: 746, exploration: 0.01, score: 229
# Scores: (min: 9, avg: 173.42, max: 500)
#
# Run: 747, exploration: 0.01, score: 329
# Scores: (min: 9, avg: 176.54, max: 500)
#
# Run: 748, exploration: 0.01, score: 337
# Scores: (min: 9, avg: 179.76, max: 500)
#
# Run: 749, exploration: 0.01, score: 230
# Scores: (min: 9, avg: 181.96, max: 500)
#
# Run: 750, exploration: 0.01, score: 262
# Scores: (min: 9, avg: 184.45, max: 500)
#
# Run: 751, exploration: 0.01, score: 212
# Scores: (min: 9, avg: 186.45, max: 500)
#
# Run: 752, exploration: 0.01, score: 299
# Scores: (min: 9, avg: 189.35, max: 500)
#
# Run: 753, exploration: 0.01, score: 373
# Scores: (min: 9, avg: 192.9, max: 500)
#
# Run: 754, exploration: 0.01, score: 231
# Scores: (min: 9, avg: 195.09, max: 500)
#
# Solved in 654 runs, 754 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-5-5c6ee6eb55f4> in cartpole()
#      88             if terminal:
#      89                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 90                 score_logger.add_score(step, run)
#      91                 break
#      92             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
# This run I will change exploration
#
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
## change expploration factor  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.05  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.9000874278732445, score: 41
# Scores: (min: 41, avg: 41, max: 41)
#
# Run: 2, exploration: 0.8020760579717637, score: 24
# Scores: (min: 24, avg: 32.5, max: 41)
#
# Run: 3, exploration: 0.7439808620067382, score: 16
# Scores: (min: 16, avg: 27, max: 41)
#
# Run: 4, exploration: 0.6832098777212641, score: 18
# Scores: (min: 16, avg: 24.75, max: 41)
#
# Run: 5, exploration: 0.6465587967553006, score: 12
# Scores: (min: 12, avg: 22.2, max: 41)
#
# Run: 6, exploration: 0.6118738784280476, score: 12
# Scores: (min: 12, avg: 20.5, max: 41)
#
# Run: 7, exploration: 0.547986285490042, score: 23
# Scores: (min: 12, avg: 20.857142857142858, max: 41)
#
# Run: 8, exploration: 0.5185893309484582, score: 12
# Scores: (min: 12, avg: 19.75, max: 41)
#
# Run: 9, exploration: 0.4858739637363176, score: 14
# Scores: (min: 12, avg: 19.11111111111111, max: 41)
#
# Run: 10, exploration: 0.4222502236424958, score: 29
# Scores: (min: 12, avg: 20.1, max: 41)
#
# Run: 11, exploration: 0.3995984329713264, score: 12
# Scores: (min: 12, avg: 19.363636363636363, max: 41)
#
# Run: 12, exploration: 0.37627099809304654, score: 13
# Scores: (min: 12, avg: 18.833333333333332, max: 41)
#
# Run: 13, exploration: 0.3596735257153405, score: 10
# Scores: (min: 10, avg: 18.153846153846153, max: 41)
#
# Run: 14, exploration: 0.3438081748424137, score: 10
# Scores: (min: 10, avg: 17.571428571428573, max: 41)
#
# Run: 15, exploration: 0.3302941218954743, score: 9
# Scores: (min: 9, avg: 17, max: 41)
#
# Run: 16, exploration: 0.3173112652388396, score: 9
# Scores: (min: 9, avg: 16.5, max: 41)
#
# Run: 17, exploration: 0.3033145315372582, score: 10
# Scores: (min: 9, avg: 16.11764705882353, max: 41)
#
# Run: 18, exploration: 0.2913921604631864, score: 9
# Scores: (min: 9, avg: 15.722222222222221, max: 41)
#
# Run: 19, exploration: 0.2743815040481898, score: 13
# Scores: (min: 9, avg: 15.578947368421053, max: 41)
#
# Run: 20, exploration: 0.2609670281126685, score: 11
# Scores: (min: 9, avg: 15.35, max: 41)
#
# Run: 21, exploration: 0.2494556624678441, score: 10
# Scores: (min: 9, avg: 15.095238095238095, max: 41)
#
# Run: 22, exploration: 0.23965031961336, score: 9
# Scores: (min: 9, avg: 14.818181818181818, max: 41)
#
# Run: 23, exploration: 0.22679417751985861, score: 12
# Scores: (min: 9, avg: 14.695652173913043, max: 41)
#
# Run: 24, exploration: 0.21462770857094118, score: 12
# Scores: (min: 9, avg: 14.583333333333334, max: 41)
#
# Run: 25, exploration: 0.20516038984972615, score: 10
# Scores: (min: 9, avg: 14.4, max: 41)
#
# Run: 26, exploration: 0.19415447453059972, score: 12
# Scores: (min: 9, avg: 14.307692307692308, max: 41)
#
# Run: 27, exploration: 0.182820281282489, score: 13
# Scores: (min: 9, avg: 14.25925925925926, max: 41)
#
# Run: 28, exploration: 0.1730128104744653, score: 12
# Scores: (min: 9, avg: 14.178571428571429, max: 41)
#
# Run: 29, exploration: 0.1662122034722543, score: 9
# Scores: (min: 9, avg: 14, max: 41)
#
# Run: 30, exploration: 0.1580861105294992, score: 11
# Scores: (min: 9, avg: 13.9, max: 41)
#
# Run: 31, exploration: 0.1526354036900377, score: 8
# Scores: (min: 8, avg: 13.709677419354838, max: 41)
#
# Run: 32, exploration: 0.14157986400593744, score: 16
# Scores: (min: 8, avg: 13.78125, max: 41)
#
# Run: 33, exploration: 0.1313250884614265, score: 16
# Scores: (min: 8, avg: 13.848484848484848, max: 41)
#
# Run: 34, exploration: 0.12365869841532712, score: 13
# Scores: (min: 8, avg: 13.823529411764707, max: 41)
#
# Run: 35, exploration: 0.11643985070121858, score: 13
# Scores: (min: 8, avg: 13.8, max: 41)
#
# Run: 36, exploration: 0.10964241905397228, score: 13
# Scores: (min: 8, avg: 13.777777777777779, max: 41)
#
# Run: 37, exploration: 0.10221196540767843, score: 15
# Scores: (min: 8, avg: 13.81081081081081, max: 41)
#
# Run: 38, exploration: 0.09721483575406, score: 11
# Scores: (min: 8, avg: 13.736842105263158, max: 41)
#
# Run: 39, exploration: 0.09246201511725258, score: 11
# Scores: (min: 8, avg: 13.666666666666666, max: 41)
#
# Run: 40, exploration: 0.0888276147181114, score: 9
# Scores: (min: 8, avg: 13.55, max: 41)
#
# Run: 41, exploration: 0.08533607153708872, score: 9
# Scores: (min: 8, avg: 13.439024390243903, max: 41)
#
# Run: 42, exploration: 0.08157186144027828, score: 10
# Scores: (min: 8, avg: 13.357142857142858, max: 41)
#
# Run: 43, exploration: 0.07528520976374668, score: 17
# Scores: (min: 8, avg: 13.44186046511628, max: 41)
#
# Run: 44, exploration: 0.0667518955258533, score: 25
# Scores: (min: 8, avg: 13.704545454545455, max: 41)
#
# Run: 45, exploration: 0.06412808167716157, score: 9
# Scores: (min: 8, avg: 13.6, max: 41)
#
# Run: 46, exploration: 0.06008254194952879, score: 14
# Scores: (min: 8, avg: 13.608695652173912, max: 41)
#
# Run: 47, exploration: 0.05685938874076987, score: 12
# Scores: (min: 8, avg: 13.574468085106384, max: 41)
#
# Run: 48, exploration: 0.05462441922520914, score: 9
# Scores: (min: 8, avg: 13.479166666666666, max: 41)
#
# Run: 49, exploration: 0.052214913061211746, score: 10
# Scores: (min: 8, avg: 13.408163265306122, max: 41)
#
# Run: 50, exploration: 0.050162503748802344, score: 9
# Scores: (min: 8, avg: 13.32, max: 41)
#
# Run: 51, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 13.254901960784315, max: 41)
#
# Run: 52, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 13.192307692307692, max: 41)
#
# Run: 53, exploration: 0.05, score: 13
# Scores: (min: 8, avg: 13.18867924528302, max: 41)
#
# Run: 54, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 13.11111111111111, max: 41)
#
# Run: 55, exploration: 0.05, score: 15
# Scores: (min: 8, avg: 13.145454545454545, max: 41)
#
# Run: 56, exploration: 0.05, score: 14
# Scores: (min: 8, avg: 13.160714285714286, max: 41)
#
# Run: 57, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 13.105263157894736, max: 41)
#
# Run: 58, exploration: 0.05, score: 34
# Scores: (min: 8, avg: 13.46551724137931, max: 41)
#
# Run: 59, exploration: 0.05, score: 11
# Scores: (min: 8, avg: 13.423728813559322, max: 41)
#
# Run: 60, exploration: 0.05, score: 21
# Scores: (min: 8, avg: 13.55, max: 41)
#
# Run: 61, exploration: 0.05, score: 16
# Scores: (min: 8, avg: 13.59016393442623, max: 41)
#
# Run: 62, exploration: 0.05, score: 13
# Scores: (min: 8, avg: 13.580645161290322, max: 41)
#
# Run: 63, exploration: 0.05, score: 27
# Scores: (min: 8, avg: 13.793650793650794, max: 41)
#
# Run: 64, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 13.734375, max: 41)
#
# Run: 65, exploration: 0.05, score: 11
# Scores: (min: 8, avg: 13.692307692307692, max: 41)
#
# Run: 66, exploration: 0.05, score: 14
# Scores: (min: 8, avg: 13.696969696969697, max: 41)
#
# Run: 67, exploration: 0.05, score: 12
# Scores: (min: 8, avg: 13.671641791044776, max: 41)
#
# Run: 68, exploration: 0.05, score: 16
# Scores: (min: 8, avg: 13.705882352941176, max: 41)
#
# Run: 69, exploration: 0.05, score: 14
# Scores: (min: 8, avg: 13.710144927536232, max: 41)
#
# Run: 70, exploration: 0.05, score: 14
# Scores: (min: 8, avg: 13.714285714285714, max: 41)
#
# Run: 71, exploration: 0.05, score: 22
# Scores: (min: 8, avg: 13.830985915492958, max: 41)
#
# Run: 72, exploration: 0.05, score: 22
# Scores: (min: 8, avg: 13.944444444444445, max: 41)
#
# Run: 73, exploration: 0.05, score: 28
# Scores: (min: 8, avg: 14.136986301369863, max: 41)
#
# Run: 74, exploration: 0.05, score: 23
# Scores: (min: 8, avg: 14.256756756756756, max: 41)
#
# Run: 75, exploration: 0.05, score: 21
# Scores: (min: 8, avg: 14.346666666666666, max: 41)
#
# Run: 76, exploration: 0.05, score: 62
# Scores: (min: 8, avg: 14.973684210526315, max: 62)
#
# Run: 77, exploration: 0.05, score: 29
# Scores: (min: 8, avg: 15.155844155844155, max: 62)
#
# Run: 78, exploration: 0.05, score: 24
# Scores: (min: 8, avg: 15.26923076923077, max: 62)
#
# Run: 79, exploration: 0.05, score: 19
# Scores: (min: 8, avg: 15.316455696202532, max: 62)
#
# Run: 80, exploration: 0.05, score: 132
# Scores: (min: 8, avg: 16.775, max: 132)
#
# Run: 81, exploration: 0.05, score: 150
# Scores: (min: 8, avg: 18.419753086419753, max: 150)
#
# Run: 82, exploration: 0.05, score: 25
# Scores: (min: 8, avg: 18.5, max: 150)
#
# Run: 83, exploration: 0.05, score: 20
# Scores: (min: 8, avg: 18.518072289156628, max: 150)
#
# Run: 84, exploration: 0.05, score: 49
# Scores: (min: 8, avg: 18.88095238095238, max: 150)
#
# Run: 85, exploration: 0.05, score: 20
# Scores: (min: 8, avg: 18.894117647058824, max: 150)
#
# Run: 86, exploration: 0.05, score: 22
# Scores: (min: 8, avg: 18.930232558139537, max: 150)
#
# Run: 87, exploration: 0.05, score: 18
# Scores: (min: 8, avg: 18.919540229885058, max: 150)
# Run: 88, exploration: 0.05, score: 25
# Scores: (min: 8, avg: 18.988636363636363, max: 150)
#
# Run: 89, exploration: 0.05, score: 29
# Scores: (min: 8, avg: 19.10112359550562, max: 150)
#
# Run: 90, exploration: 0.05, score: 50
# Scores: (min: 8, avg: 19.444444444444443, max: 150)
#
# Run: 91, exploration: 0.05, score: 47
# Scores: (min: 8, avg: 19.747252747252748, max: 150)
#
# Run: 92, exploration: 0.05, score: 41
# Scores: (min: 8, avg: 19.97826086956522, max: 150)
#
# Run: 93, exploration: 0.05, score: 125
# Scores: (min: 8, avg: 21.107526881720432, max: 150)
#
# Run: 94, exploration: 0.05, score: 176
# Scores: (min: 8, avg: 22.75531914893617, max: 176)
#
# Run: 95, exploration: 0.05, score: 95
# Scores: (min: 8, avg: 23.51578947368421, max: 176)
#
# Run: 96, exploration: 0.05, score: 188
# Scores: (min: 8, avg: 25.229166666666668, max: 188)
#
# Run: 97, exploration: 0.05, score: 138
# Scores: (min: 8, avg: 26.391752577319586, max: 188)
#
# Run: 98, exploration: 0.05, score: 117
# Scores: (min: 8, avg: 27.316326530612244, max: 188)
#
# Run: 99, exploration: 0.05, score: 212
# Scores: (min: 8, avg: 29.181818181818183, max: 212)
#
# Run: 100, exploration: 0.05, score: 158
# Scores: (min: 8, avg: 30.47, max: 212)
#
# Run: 101, exploration: 0.05, score: 131
# Scores: (min: 8, avg: 31.37, max: 212)
#
# Run: 102, exploration: 0.05, score: 117
# Scores: (min: 8, avg: 32.3, max: 212)
#
# Run: 103, exploration: 0.05, score: 167
# Scores: (min: 8, avg: 33.81, max: 212)
#
# Run: 104, exploration: 0.05, score: 96
# Scores: (min: 8, avg: 34.59, max: 212)
#
# Run: 105, exploration: 0.05, score: 154
# Scores: (min: 8, avg: 36.01, max: 212)
#
# Run: 106, exploration: 0.05, score: 150
# Scores: (min: 8, avg: 37.39, max: 212)
#
# Run: 107, exploration: 0.05, score: 127
# Scores: (min: 8, avg: 38.43, max: 212)
#
# Run: 108, exploration: 0.05, score: 212
# Scores: (min: 8, avg: 40.43, max: 212)
#
# Run: 109, exploration: 0.05, score: 170
# Scores: (min: 8, avg: 41.99, max: 212)
#
# Run: 110, exploration: 0.05, score: 147
# Scores: (min: 8, avg: 43.17, max: 212)
#
# Run: 111, exploration: 0.05, score: 125
# Scores: (min: 8, avg: 44.3, max: 212)
#
# Run: 112, exploration: 0.05, score: 177
# Scores: (min: 8, avg: 45.94, max: 212)
#
# Run: 113, exploration: 0.05, score: 156
# Scores: (min: 8, avg: 47.4, max: 212)
#
# Run: 114, exploration: 0.05, score: 159
# Scores: (min: 8, avg: 48.89, max: 212)
#
# Run: 115, exploration: 0.05, score: 138
# Scores: (min: 8, avg: 50.18, max: 212)
#
# Run: 116, exploration: 0.05, score: 204
# Scores: (min: 8, avg: 52.13, max: 212)
#
# Run: 117, exploration: 0.05, score: 166
# Scores: (min: 8, avg: 53.69, max: 212)
#
# Run: 118, exploration: 0.05, score: 193
# Scores: (min: 8, avg: 55.53, max: 212)
#
# Run: 119, exploration: 0.05, score: 138
# Scores: (min: 8, avg: 56.78, max: 212)
#
# Run: 120, exploration: 0.05, score: 147
# Scores: (min: 8, avg: 58.14, max: 212)
#
# Run: 121, exploration: 0.05, score: 117
# Scores: (min: 8, avg: 59.21, max: 212)
#
# Run: 122, exploration: 0.05, score: 136
# Scores: (min: 8, avg: 60.48, max: 212)
#
# Run: 123, exploration: 0.05, score: 160
# Scores: (min: 8, avg: 61.96, max: 212)
#
# Run: 124, exploration: 0.05, score: 187
# Scores: (min: 8, avg: 63.71, max: 212)
#
# Run: 125, exploration: 0.05, score: 175
# Scores: (min: 8, avg: 65.36, max: 212)
#
# Run: 126, exploration: 0.05, score: 214
# Scores: (min: 8, avg: 67.38, max: 214)
#
# Run: 127, exploration: 0.05, score: 192
# Scores: (min: 8, avg: 69.17, max: 214)
#
# Run: 128, exploration: 0.05, score: 149
# Scores: (min: 8, avg: 70.54, max: 214)
#
# Run: 129, exploration: 0.05, score: 131
# Scores: (min: 8, avg: 71.76, max: 214)
#
# Run: 130, exploration: 0.05, score: 181
# Scores: (min: 8, avg: 73.46, max: 214)
#
# Run: 131, exploration: 0.05, score: 174
# Scores: (min: 9, avg: 75.12, max: 214)
#
# Run: 132, exploration: 0.05, score: 191
# Scores: (min: 9, avg: 76.87, max: 214)
#
# Run: 133, exploration: 0.05, score: 179
# Scores: (min: 9, avg: 78.5, max: 214)
#
# Run: 134, exploration: 0.05, score: 205
# Scores: (min: 9, avg: 80.42, max: 214)
#
# Run: 135, exploration: 0.05, score: 182
# Scores: (min: 9, avg: 82.11, max: 214)
#
# Run: 136, exploration: 0.05, score: 35
# Scores: (min: 9, avg: 82.33, max: 214)
#
# Run: 137, exploration: 0.05, score: 161
# Scores: (min: 9, avg: 83.79, max: 214)
#
# Run: 138, exploration: 0.05, score: 169
# Scores: (min: 9, avg: 85.37, max: 214)
#
# Run: 139, exploration: 0.05, score: 240
# Scores: (min: 9, avg: 87.66, max: 240)
#
# Run: 140, exploration: 0.05, score: 189
# Scores: (min: 9, avg: 89.46, max: 240)
#
# Run: 141, exploration: 0.05, score: 171
# Scores: (min: 9, avg: 91.08, max: 240)
#
# Run: 142, exploration: 0.05, score: 157
# Scores: (min: 9, avg: 92.55, max: 240)
#
# Run: 143, exploration: 0.05, score: 197
# Scores: (min: 9, avg: 94.35, max: 240)
#
# Run: 144, exploration: 0.05, score: 157
# Scores: (min: 9, avg: 95.67, max: 240)
#
# Run: 145, exploration: 0.05, score: 139
# Scores: (min: 9, avg: 96.97, max: 240)
#
# Run: 146, exploration: 0.05, score: 142
# Scores: (min: 9, avg: 98.25, max: 240)
#
# Run: 147, exploration: 0.05, score: 169
# Scores: (min: 9, avg: 99.82, max: 240)
#
# Run: 148, exploration: 0.05, score: 222
# Scores: (min: 9, avg: 101.95, max: 240)
#
# Run: 149, exploration: 0.05, score: 349
# Scores: (min: 9, avg: 105.34, max: 349)
#
# Run: 150, exploration: 0.05, score: 169
# Scores: (min: 9, avg: 106.94, max: 349)
#
# Run: 151, exploration: 0.05, score: 164
# Scores: (min: 9, avg: 108.48, max: 349)
#
# Run: 152, exploration: 0.05, score: 148
# Scores: (min: 9, avg: 109.86, max: 349)
#
# Run: 153, exploration: 0.05, score: 241
# Scores: (min: 9, avg: 112.14, max: 349)
#
# Run: 154, exploration: 0.05, score: 170
# Scores: (min: 10, avg: 113.75, max: 349)
#
# Run: 155, exploration: 0.05, score: 221
# Scores: (min: 10, avg: 115.81, max: 349)
#
# Run: 156, exploration: 0.05, score: 71
# Scores: (min: 10, avg: 116.38, max: 349)
#
# Run: 157, exploration: 0.05, score: 139
# Scores: (min: 10, avg: 117.67, max: 349)
#
# Run: 158, exploration: 0.05, score: 172
# Scores: (min: 10, avg: 119.05, max: 349)
#
# Run: 159, exploration: 0.05, score: 140
# Scores: (min: 10, avg: 120.34, max: 349)
#
# Run: 160, exploration: 0.05, score: 177
# Scores: (min: 10, avg: 121.9, max: 349)
#
# Run: 161, exploration: 0.05, score: 159
# Scores: (min: 10, avg: 123.33, max: 349)
#
# Run: 162, exploration: 0.05, score: 180
# Scores: (min: 10, avg: 125, max: 349)
#
# Run: 163, exploration: 0.05, score: 96
# Scores: (min: 10, avg: 125.69, max: 349)
#
# Run: 164, exploration: 0.05, score: 200
# Scores: (min: 11, avg: 127.59, max: 349)
#
# Run: 165, exploration: 0.05, score: 162
# Scores: (min: 12, avg: 129.1, max: 349)
#
# Run: 166, exploration: 0.05, score: 152
# Scores: (min: 12, avg: 130.48, max: 349)
#
# Run: 167, exploration: 0.05, score: 147
# Scores: (min: 14, avg: 131.83, max: 349)
#
# Run: 168, exploration: 0.05, score: 286
# Scores: (min: 14, avg: 134.53, max: 349)
#
# Run: 169, exploration: 0.05, score: 172
# Scores: (min: 14, avg: 136.11, max: 349)
#
# Run: 170, exploration: 0.05, score: 173
# Scores: (min: 18, avg: 137.7, max: 349)
#
# Run: 171, exploration: 0.05, score: 202
# Scores: (min: 18, avg: 139.5, max: 349)
#
# Run: 172, exploration: 0.05, score: 102
# Scores: (min: 18, avg: 140.3, max: 349)
#
# Run: 173, exploration: 0.05, score: 135
# Scores: (min: 18, avg: 141.37, max: 349)
#
# Run: 174, exploration: 0.05, score: 283
# Scores: (min: 18, avg: 143.97, max: 349)
#
# Run: 175, exploration: 0.05, score: 176
# Scores: (min: 18, avg: 145.52, max: 349)
#
# Run: 176, exploration: 0.05, score: 59
# Scores: (min: 18, avg: 145.49, max: 349)
#
# Run: 177, exploration: 0.05, score: 68
# Scores: (min: 18, avg: 145.88, max: 349)
#
# Run: 178, exploration: 0.05, score: 155
# Scores: (min: 18, avg: 147.19, max: 349)
#
# Run: 179, exploration: 0.05, score: 79
# Scores: (min: 18, avg: 147.79, max: 349)
#
# Run: 180, exploration: 0.05, score: 185
# Scores: (min: 18, avg: 148.32, max: 349)
#
# Run: 181, exploration: 0.05, score: 135
# Scores: (min: 18, avg: 148.17, max: 349)
#
# Run: 182, exploration: 0.05, score: 206
# Scores: (min: 18, avg: 149.98, max: 349)
#
# Run: 183, exploration: 0.05, score: 179
# Scores: (min: 18, avg: 151.57, max: 349)
#
# Run: 184, exploration: 0.05, score: 154
# Scores: (min: 18, avg: 152.62, max: 349)
#
# Run: 185, exploration: 0.05, score: 166
# Scores: (min: 18, avg: 154.08, max: 349)
#
# Run: 186, exploration: 0.05, score: 86
# Scores: (min: 18, avg: 154.72, max: 349)
#
# Run: 187, exploration: 0.05, score: 123
# Scores: (min: 25, avg: 155.77, max: 349)
#
# Run: 188, exploration: 0.05, score: 251
# Scores: (min: 29, avg: 158.03, max: 349)
# Run: 189, exploration: 0.05, score: 267
# Scores: (min: 35, avg: 160.41, max: 349)
#
# Run: 190, exploration: 0.05, score: 75
# Scores: (min: 35, avg: 160.66, max: 349)
#
# Run: 191, exploration: 0.05, score: 146
# Scores: (min: 35, avg: 161.65, max: 349)
#
# Run: 192, exploration: 0.05, score: 293
# Scores: (min: 35, avg: 164.17, max: 349)
#
# Run: 193, exploration: 0.05, score: 228
# Scores: (min: 35, avg: 165.2, max: 349)
#
# Run: 194, exploration: 0.05, score: 141
# Scores: (min: 35, avg: 164.85, max: 349)
#
# Run: 195, exploration: 0.05, score: 108
# Scores: (min: 35, avg: 164.98, max: 349)
#
# Run: 196, exploration: 0.05, score: 119
# Scores: (min: 35, avg: 164.29, max: 349)
#
# Run: 197, exploration: 0.05, score: 193
# Scores: (min: 35, avg: 164.84, max: 349)
#
# Run: 198, exploration: 0.05, score: 194
# Scores: (min: 35, avg: 165.61, max: 349)
#
# Run: 199, exploration: 0.05, score: 144
# Scores: (min: 35, avg: 164.93, max: 349)
#
# Run: 200, exploration: 0.05, score: 101
# Scores: (min: 35, avg: 164.36, max: 349)
#
# Run: 201, exploration: 0.05, score: 102
# Scores: (min: 35, avg: 164.07, max: 349)
#
# Run: 202, exploration: 0.05, score: 122
# Scores: (min: 35, avg: 164.12, max: 349)
#
# Run: 203, exploration: 0.05, score: 135
# Scores: (min: 35, avg: 163.8, max: 349)
#
# Run: 204, exploration: 0.05, score: 202
# Scores: (min: 35, avg: 164.86, max: 349)
#
# Run: 205, exploration: 0.05, score: 109
# Scores: (min: 35, avg: 164.41, max: 349)
#
# Run: 206, exploration: 0.05, score: 136
# Scores: (min: 35, avg: 164.27, max: 349)
#
# Run: 207, exploration: 0.05, score: 178
# Scores: (min: 35, avg: 164.78, max: 349)
#
# Run: 208, exploration: 0.05, score: 143
# Scores: (min: 35, avg: 164.09, max: 349)
#
# Run: 209, exploration: 0.05, score: 91
# Scores: (min: 35, avg: 163.3, max: 349)
#
# Run: 210, exploration: 0.05, score: 166
# Scores: (min: 35, avg: 163.49, max: 349)
#
# Run: 211, exploration: 0.05, score: 130
# Scores: (min: 35, avg: 163.54, max: 349)
#
# Run: 212, exploration: 0.05, score: 10
# Scores: (min: 10, avg: 161.87, max: 349)
#
# Run: 213, exploration: 0.05, score: 28
# Scores: (min: 10, avg: 160.59, max: 349)
#
# Run: 214, exploration: 0.05, score: 140
# Scores: (min: 10, avg: 160.4, max: 349)
#
# Run: 215, exploration: 0.05, score: 63
# Scores: (min: 10, avg: 159.65, max: 349)
#
# Run: 216, exploration: 0.05, score: 235
# Scores: (min: 10, avg: 159.96, max: 349)
#
# Run: 217, exploration: 0.05, score: 39
# Scores: (min: 10, avg: 158.69, max: 349)
#
# Run: 218, exploration: 0.05, score: 26
# Scores: (min: 10, avg: 157.02, max: 349)
#
# Run: 219, exploration: 0.05, score: 136
# Scores: (min: 10, avg: 157, max: 349)
#
# Run: 220, exploration: 0.05, score: 203
# Scores: (min: 10, avg: 157.56, max: 349)
#
# Run: 221, exploration: 0.05, score: 170
# Scores: (min: 10, avg: 158.09, max: 349)
#
# Run: 222, exploration: 0.05, score: 117
# Scores: (min: 10, avg: 157.9, max: 349)
#
# Run: 223, exploration: 0.05, score: 157
# Scores: (min: 10, avg: 157.87, max: 349)
#
# Run: 224, exploration: 0.05, score: 175
# Scores: (min: 10, avg: 157.75, max: 349)
#
# Run: 225, exploration: 0.05, score: 164
# Scores: (min: 10, avg: 157.64, max: 349)
#
# Run: 226, exploration: 0.05, score: 83
# Scores: (min: 10, avg: 156.33, max: 349)
#
# Run: 227, exploration: 0.05, score: 182
# Scores: (min: 10, avg: 156.23, max: 349)
#
# Run: 228, exploration: 0.05, score: 98
# Scores: (min: 10, avg: 155.72, max: 349)
#
# Run: 229, exploration: 0.05, score: 140
# Scores: (min: 10, avg: 155.81, max: 349)
#
# Run: 230, exploration: 0.05, score: 70
# Scores: (min: 10, avg: 154.7, max: 349)
#
# Run: 231, exploration: 0.05, score: 144
# Scores: (min: 10, avg: 154.4, max: 349)
#
# Run: 232, exploration: 0.05, score: 156
# Scores: (min: 10, avg: 154.05, max: 349)
#
# Run: 233, exploration: 0.05, score: 54
# Scores: (min: 10, avg: 152.8, max: 349)
#
# Run: 234, exploration: 0.05, score: 40
# Scores: (min: 10, avg: 151.15, max: 349)
#
# Run: 235, exploration: 0.05, score: 110
# Scores: (min: 10, avg: 150.43, max: 349)
#
# Run: 236, exploration: 0.05, score: 299
# Scores: (min: 10, avg: 153.07, max: 349)
#
# Run: 237, exploration: 0.05, score: 135
# Scores: (min: 10, avg: 152.81, max: 349)
#
# Run: 238, exploration: 0.05, score: 230
# Scores: (min: 10, avg: 153.42, max: 349)
#
# Run: 239, exploration: 0.05, score: 160
# Scores: (min: 10, avg: 152.62, max: 349)
#
# Run: 240, exploration: 0.05, score: 132
# Scores: (min: 10, avg: 152.05, max: 349)
#
# Run: 241, exploration: 0.05, score: 173
# Scores: (min: 10, avg: 152.07, max: 349)
#
# Run: 242, exploration: 0.05, score: 88
# Scores: (min: 10, avg: 151.38, max: 349)
#
# Run: 243, exploration: 0.05, score: 132
# Scores: (min: 10, avg: 150.73, max: 349)
#
# Run: 244, exploration: 0.05, score: 106
# Scores: (min: 10, avg: 150.22, max: 349)
#
# Run: 245, exploration: 0.05, score: 169
# Scores: (min: 10, avg: 150.52, max: 349)
#
# Run: 246, exploration: 0.05, score: 84
# Scores: (min: 10, avg: 149.94, max: 349)
#
# Run: 247, exploration: 0.05, score: 121
# Scores: (min: 10, avg: 149.46, max: 349)
#
# Run: 248, exploration: 0.05, score: 166
# Scores: (min: 10, avg: 148.9, max: 349)
#
# Run: 249, exploration: 0.05, score: 213
# Scores: (min: 10, avg: 147.54, max: 299)
#
# Run: 250, exploration: 0.05, score: 217
# Scores: (min: 10, avg: 148.02, max: 299)
#
# Run: 251, exploration: 0.05, score: 125
# Scores: (min: 10, avg: 147.63, max: 299)
#
# Run: 252, exploration: 0.05, score: 96
# Scores: (min: 10, avg: 147.11, max: 299)
#
# Run: 253, exploration: 0.05, score: 252
# Scores: (min: 10, avg: 147.22, max: 299)
#
# Run: 254, exploration: 0.05, score: 140
# Scores: (min: 10, avg: 146.92, max: 299)
#
# Run: 255, exploration: 0.05, score: 131
# Scores: (min: 10, avg: 146.02, max: 299)
#
# Run: 256, exploration: 0.05, score: 17
# Scores: (min: 10, avg: 145.48, max: 299)
#
# Run: 257, exploration: 0.05, score: 114
# Scores: (min: 10, avg: 145.23, max: 299)
#
# Run: 258, exploration: 0.05, score: 147
# Scores: (min: 10, avg: 144.98, max: 299)
#
# Run: 259, exploration: 0.05, score: 126
# Scores: (min: 10, avg: 144.84, max: 299)
#
# Run: 260, exploration: 0.05, score: 124
# Scores: (min: 10, avg: 144.31, max: 299)
#
# Run: 261, exploration: 0.05, score: 163
# Scores: (min: 10, avg: 144.35, max: 299)
#
# Run: 262, exploration: 0.05, score: 25
# Scores: (min: 10, avg: 142.8, max: 299)
#
# Run: 263, exploration: 0.05, score: 234
# Scores: (min: 10, avg: 144.18, max: 299)
#
# Run: 264, exploration: 0.05, score: 155
# Scores: (min: 10, avg: 143.73, max: 299)
#
# Run: 265, exploration: 0.05, score: 266
# Scores: (min: 10, avg: 144.77, max: 299)
#
# Run: 266, exploration: 0.05, score: 98
# Scores: (min: 10, avg: 144.23, max: 299)
#
# Run: 267, exploration: 0.05, score: 99
# Scores: (min: 10, avg: 143.75, max: 299)
#
# Run: 268, exploration: 0.05, score: 159
# Scores: (min: 10, avg: 142.48, max: 299)
#
# Run: 269, exploration: 0.05, score: 125
# Scores: (min: 10, avg: 142.01, max: 299)
#
# Run: 270, exploration: 0.05, score: 149
# Scores: (min: 10, avg: 141.77, max: 299)
#
# Run: 271, exploration: 0.05, score: 167
# Scores: (min: 10, avg: 141.42, max: 299)
#
# Run: 272, exploration: 0.05, score: 127
# Scores: (min: 10, avg: 141.67, max: 299)
#
# Run: 273, exploration: 0.05, score: 199
# Scores: (min: 10, avg: 142.31, max: 299)
#
# Run: 274, exploration: 0.05, score: 101
# Scores: (min: 10, avg: 140.49, max: 299)
#
# Run: 275, exploration: 0.05, score: 213
# Scores: (min: 10, avg: 140.86, max: 299)
#
# Run: 276, exploration: 0.05, score: 197
# Scores: (min: 10, avg: 142.24, max: 299)
#
# Run: 277, exploration: 0.05, score: 126
# Scores: (min: 10, avg: 142.82, max: 299)
#
# Run: 278, exploration: 0.05, score: 152
# Scores: (min: 10, avg: 142.79, max: 299)
#
# Run: 279, exploration: 0.05, score: 136
# Scores: (min: 10, avg: 143.36, max: 299)
#
# Run: 280, exploration: 0.05, score: 253
# Scores: (min: 10, avg: 144.04, max: 299)
#
# Run: 281, exploration: 0.05, score: 159
# Scores: (min: 10, avg: 144.28, max: 299)
#
# Run: 282, exploration: 0.05, score: 149
# Scores: (min: 10, avg: 143.71, max: 299)
#
# Run: 283, exploration: 0.05, score: 293
# Scores: (min: 10, avg: 144.85, max: 299)
#
# Run: 284, exploration: 0.05, score: 145
# Scores: (min: 10, avg: 144.76, max: 299)
#
# Run: 285, exploration: 0.05, score: 197
# Scores: (min: 10, avg: 145.07, max: 299)
#
# Run: 286, exploration: 0.05, score: 99
# Scores: (min: 10, avg: 145.2, max: 299)
#
# Run: 287, exploration: 0.05, score: 219
# Scores: (min: 10, avg: 146.16, max: 299)
#
# Run: 288, exploration: 0.05, score: 226
# Scores: (min: 10, avg: 145.91, max: 299)
#
# Run: 289, exploration: 0.05, score: 266
# Scores: (min: 10, avg: 145.9, max: 299)
# Run: 290, exploration: 0.05, score: 120
# Scores: (min: 10, avg: 146.35, max: 299)
#
# Run: 291, exploration: 0.05, score: 500
# Scores: (min: 10, avg: 149.89, max: 500)
#
# Run: 292, exploration: 0.05, score: 102
# Scores: (min: 10, avg: 147.98, max: 500)
#
# Run: 293, exploration: 0.05, score: 142
# Scores: (min: 10, avg: 147.12, max: 500)
#
# Run: 294, exploration: 0.05, score: 300
# Scores: (min: 10, avg: 148.71, max: 500)
#
# Run: 295, exploration: 0.05, score: 90
# Scores: (min: 10, avg: 148.53, max: 500)
#
# Run: 296, exploration: 0.05, score: 109
# Scores: (min: 10, avg: 148.43, max: 500)
#
# Run: 297, exploration: 0.05, score: 78
# Scores: (min: 10, avg: 147.28, max: 500)
#
# Run: 298, exploration: 0.05, score: 103
# Scores: (min: 10, avg: 146.37, max: 500)
#
# Run: 299, exploration: 0.05, score: 156
# Scores: (min: 10, avg: 146.49, max: 500)
#
# Run: 300, exploration: 0.05, score: 164
# Scores: (min: 10, avg: 147.12, max: 500)
#
# Run: 301, exploration: 0.05, score: 168
# Scores: (min: 10, avg: 147.78, max: 500)
#
# Run: 302, exploration: 0.05, score: 314
# Scores: (min: 10, avg: 149.7, max: 500)
#
# Run: 303, exploration: 0.05, score: 117
# Scores: (min: 10, avg: 149.52, max: 500)
#
# Run: 304, exploration: 0.05, score: 187
# Scores: (min: 10, avg: 149.37, max: 500)
#
# Run: 305, exploration: 0.05, score: 403
# Scores: (min: 10, avg: 152.31, max: 500)
#
# Run: 306, exploration: 0.05, score: 176
# Scores: (min: 10, avg: 152.71, max: 500)
#
# Run: 307, exploration: 0.05, score: 267
# Scores: (min: 10, avg: 153.6, max: 500)
#
# Run: 308, exploration: 0.05, score: 143
# Scores: (min: 10, avg: 153.6, max: 500)
#
# Run: 309, exploration: 0.05, score: 124
# Scores: (min: 10, avg: 153.93, max: 500)
#
# Run: 310, exploration: 0.05, score: 218
# Scores: (min: 10, avg: 154.45, max: 500)
#
# Run: 311, exploration: 0.05, score: 109
# Scores: (min: 10, avg: 154.24, max: 500)
#
# Run: 312, exploration: 0.05, score: 74
# Scores: (min: 17, avg: 154.88, max: 500)
#
# Run: 313, exploration: 0.05, score: 28
# Scores: (min: 17, avg: 154.88, max: 500)
#
# Run: 314, exploration: 0.05, score: 160
# Scores: (min: 17, avg: 155.08, max: 500)
#
# Run: 315, exploration: 0.05, score: 101
# Scores: (min: 17, avg: 155.46, max: 500)
#
# Run: 316, exploration: 0.05, score: 21
# Scores: (min: 17, avg: 153.32, max: 500)
#
# Run: 317, exploration: 0.05, score: 144
# Scores: (min: 17, avg: 154.37, max: 500)
#
# Run: 318, exploration: 0.05, score: 195
# Scores: (min: 17, avg: 156.06, max: 500)
#
# Run: 319, exploration: 0.05, score: 128
# Scores: (min: 17, avg: 155.98, max: 500)
#
# Run: 320, exploration: 0.05, score: 94
# Scores: (min: 17, avg: 154.89, max: 500)
#
# Run: 321, exploration: 0.05, score: 237
# Scores: (min: 17, avg: 155.56, max: 500)
#
# Run: 322, exploration: 0.05, score: 273
# Scores: (min: 17, avg: 157.12, max: 500)
#
# Run: 323, exploration: 0.05, score: 392
# Scores: (min: 17, avg: 159.47, max: 500)
#
# Run: 324, exploration: 0.05, score: 156
# Scores: (min: 17, avg: 159.28, max: 500)
#
# Run: 325, exploration: 0.05, score: 139
# Scores: (min: 17, avg: 159.03, max: 500)
#
# Run: 326, exploration: 0.05, score: 159
# Scores: (min: 17, avg: 159.79, max: 500)
#
# Run: 327, exploration: 0.05, score: 149
# Scores: (min: 17, avg: 159.46, max: 500)
#
# Run: 328, exploration: 0.05, score: 347
# Scores: (min: 17, avg: 161.95, max: 500)
#
# Run: 329, exploration: 0.05, score: 79
# Scores: (min: 17, avg: 161.34, max: 500)
#
# Run: 330, exploration: 0.05, score: 43
# Scores: (min: 17, avg: 161.07, max: 500)
#
# Run: 331, exploration: 0.05, score: 103
# Scores: (min: 17, avg: 160.66, max: 500)
#
# Run: 332, exploration: 0.05, score: 243
# Scores: (min: 17, avg: 161.53, max: 500)
#
# Run: 333, exploration: 0.05, score: 93
# Scores: (min: 17, avg: 161.92, max: 500)
#
# Run: 334, exploration: 0.05, score: 72
# Scores: (min: 17, avg: 162.24, max: 500)
#
# Run: 335, exploration: 0.05, score: 95
# Scores: (min: 17, avg: 162.09, max: 500)
#
# Run: 336, exploration: 0.05, score: 301
# Scores: (min: 17, avg: 162.11, max: 500)
#
# Run: 337, exploration: 0.05, score: 355
# Scores: (min: 17, avg: 164.31, max: 500)
#
# Run: 338, exploration: 0.05, score: 94
# Scores: (min: 17, avg: 162.95, max: 500)
#
# Run: 339, exploration: 0.05, score: 168
# Scores: (min: 17, avg: 163.03, max: 500)
#
# Run: 340, exploration: 0.05, score: 275
# Scores: (min: 17, avg: 164.46, max: 500)
#
# Run: 341, exploration: 0.05, score: 143
# Scores: (min: 17, avg: 164.16, max: 500)
#
# Run: 342, exploration: 0.05, score: 168
# Scores: (min: 17, avg: 164.96, max: 500)
#
# Run: 343, exploration: 0.05, score: 214
# Scores: (min: 17, avg: 165.78, max: 500)
#
# Run: 344, exploration: 0.05, score: 126
# Scores: (min: 17, avg: 165.98, max: 500)
#
# Run: 345, exploration: 0.05, score: 165
# Scores: (min: 17, avg: 165.94, max: 500)
#
# Run: 346, exploration: 0.05, score: 114
# Scores: (min: 17, avg: 166.24, max: 500)
#
# Run: 347, exploration: 0.05, score: 281
# Scores: (min: 17, avg: 167.84, max: 500)
#
# Run: 348, exploration: 0.05, score: 99
# Scores: (min: 17, avg: 167.17, max: 500)
#
# Run: 349, exploration: 0.05, score: 117
# Scores: (min: 17, avg: 166.21, max: 500)
#
# Run: 350, exploration: 0.05, score: 101
# Scores: (min: 17, avg: 165.05, max: 500)
#
# Run: 351, exploration: 0.05, score: 289
# Scores: (min: 17, avg: 166.69, max: 500)
#
# Run: 352, exploration: 0.05, score: 121
# Scores: (min: 17, avg: 166.94, max: 500)
#
# Run: 353, exploration: 0.05, score: 147
# Scores: (min: 17, avg: 165.89, max: 500)
#
# Run: 354, exploration: 0.05, score: 152
# Scores: (min: 17, avg: 166.01, max: 500)
#
# Run: 355, exploration: 0.05, score: 109
# Scores: (min: 17, avg: 165.79, max: 500)
#
# Run: 356, exploration: 0.05, score: 116
# Scores: (min: 21, avg: 166.78, max: 500)
#
# Run: 357, exploration: 0.05, score: 109
# Scores: (min: 21, avg: 166.73, max: 500)
#
# Run: 358, exploration: 0.05, score: 97
# Scores: (min: 21, avg: 166.23, max: 500)
#
# Run: 359, exploration: 0.05, score: 468
# Scores: (min: 21, avg: 169.65, max: 500)
#
# Run: 360, exploration: 0.05, score: 122
# Scores: (min: 21, avg: 169.63, max: 500)
#
# Run: 361, exploration: 0.05, score: 30
# Scores: (min: 21, avg: 168.3, max: 500)
#
# Run: 362, exploration: 0.05, score: 11
# Scores: (min: 11, avg: 168.16, max: 500)
#
# Run: 363, exploration: 0.05, score: 14
# Scores: (min: 11, avg: 165.96, max: 500)
#
# Run: 364, exploration: 0.05, score: 135
# Scores: (min: 11, avg: 165.76, max: 500)
#
# Run: 365, exploration: 0.05, score: 241
# Scores: (min: 11, avg: 165.51, max: 500)
#
# Run: 366, exploration: 0.05, score: 84
# Scores: (min: 11, avg: 165.37, max: 500)
#
# Run: 367, exploration: 0.05, score: 84
# Scores: (min: 11, avg: 165.22, max: 500)
#
# Run: 368, exploration: 0.05, score: 43
# Scores: (min: 11, avg: 164.06, max: 500)
#
# Run: 369, exploration: 0.05, score: 62
# Scores: (min: 11, avg: 163.43, max: 500)
#
# Run: 370, exploration: 0.05, score: 22
# Scores: (min: 11, avg: 162.16, max: 500)
#
# Run: 371, exploration: 0.05, score: 108
# Scores: (min: 11, avg: 161.57, max: 500)
#
# Run: 372, exploration: 0.05, score: 90
# Scores: (min: 11, avg: 161.2, max: 500)
#
# Run: 373, exploration: 0.05, score: 106
# Scores: (min: 11, avg: 160.27, max: 500)
#
# Run: 374, exploration: 0.05, score: 124
# Scores: (min: 11, avg: 160.5, max: 500)
#
# Run: 375, exploration: 0.05, score: 108
# Scores: (min: 11, avg: 159.45, max: 500)
#
# Run: 376, exploration: 0.05, score: 109
# Scores: (min: 11, avg: 158.57, max: 500)
#
# Run: 377, exploration: 0.05, score: 96
# Scores: (min: 11, avg: 158.27, max: 500)
#
# Run: 378, exploration: 0.05, score: 162
# Scores: (min: 11, avg: 158.37, max: 500)
#
# Run: 379, exploration: 0.05, score: 102
# Scores: (min: 11, avg: 158.03, max: 500)
#
# Run: 380, exploration: 0.05, score: 117
# Scores: (min: 11, avg: 156.67, max: 500)
#
# Run: 381, exploration: 0.05, score: 46
# Scores: (min: 11, avg: 155.54, max: 500)
#
# Run: 382, exploration: 0.05, score: 48
# Scores: (min: 11, avg: 154.53, max: 500)
#
# Run: 383, exploration: 0.05, score: 108
# Scores: (min: 11, avg: 152.68, max: 500)
#
# Run: 384, exploration: 0.05, score: 54
# Scores: (min: 11, avg: 151.77, max: 500)
#
# Run: 385, exploration: 0.05, score: 229
# Scores: (min: 11, avg: 152.09, max: 500)
#
# Run: 386, exploration: 0.05, score: 223
# Scores: (min: 11, avg: 153.33, max: 500)
#
# Run: 387, exploration: 0.05, score: 92
# Scores: (min: 11, avg: 152.06, max: 500)
#
# Run: 388, exploration: 0.05, score: 120
# Scores: (min: 11, avg: 151, max: 500)
#
# Run: 389, exploration: 0.05, score: 125
# Scores: (min: 11, avg: 149.59, max: 500)
#
# Run: 390, exploration: 0.05, score: 108
# Scores: (min: 11, avg: 149.47, max: 500)
# Run: 391, exploration: 0.05, score: 132
# Scores: (min: 11, avg: 145.79, max: 468)
#
# Run: 392, exploration: 0.05, score: 89
# Scores: (min: 11, avg: 145.66, max: 468)
#
# Run: 393, exploration: 0.05, score: 185
# Scores: (min: 11, avg: 146.09, max: 468)
#
# Run: 394, exploration: 0.05, score: 29
# Scores: (min: 11, avg: 143.38, max: 468)
#
# Run: 395, exploration: 0.05, score: 148
# Scores: (min: 11, avg: 143.96, max: 468)
#
# Run: 396, exploration: 0.05, score: 253
# Scores: (min: 11, avg: 145.4, max: 468)
#
# Run: 397, exploration: 0.05, score: 170
# Scores: (min: 11, avg: 146.32, max: 468)
#
# Run: 398, exploration: 0.05, score: 143
# Scores: (min: 11, avg: 146.72, max: 468)
#
# Run: 399, exploration: 0.05, score: 85
# Scores: (min: 11, avg: 146.01, max: 468)
#
# Run: 400, exploration: 0.05, score: 180
# Scores: (min: 11, avg: 146.17, max: 468)
#
# Run: 401, exploration: 0.05, score: 115
# Scores: (min: 11, avg: 145.64, max: 468)
#
# Run: 402, exploration: 0.05, score: 78
# Scores: (min: 11, avg: 143.28, max: 468)
#
# Run: 403, exploration: 0.05, score: 209
# Scores: (min: 11, avg: 144.2, max: 468)
#
# Run: 404, exploration: 0.05, score: 407
# Scores: (min: 11, avg: 146.4, max: 468)
#
# Run: 405, exploration: 0.05, score: 489
# Scores: (min: 11, avg: 147.26, max: 489)
#
# Run: 406, exploration: 0.05, score: 190
# Scores: (min: 11, avg: 147.4, max: 489)
#
# Run: 407, exploration: 0.05, score: 145
# Scores: (min: 11, avg: 146.18, max: 489)
#
# Run: 408, exploration: 0.05, score: 11
# Scores: (min: 11, avg: 144.86, max: 489)
#
# Run: 409, exploration: 0.05, score: 217
# Scores: (min: 11, avg: 145.79, max: 489)
#
# Run: 410, exploration: 0.05, score: 27
# Scores: (min: 11, avg: 143.88, max: 489)
#
# Run: 411, exploration: 0.05, score: 43
# Scores: (min: 11, avg: 143.22, max: 489)
#
# Run: 412, exploration: 0.05, score: 98
# Scores: (min: 11, avg: 143.46, max: 489)
#
# Run: 413, exploration: 0.05, score: 151
# Scores: (min: 11, avg: 144.69, max: 489)
#
# Run: 414, exploration: 0.05, score: 90
# Scores: (min: 11, avg: 143.99, max: 489)
#
# Run: 415, exploration: 0.05, score: 113
# Scores: (min: 11, avg: 144.11, max: 489)
#
# Run: 416, exploration: 0.05, score: 252
# Scores: (min: 11, avg: 146.42, max: 489)
#
# Run: 417, exploration: 0.05, score: 236
# Scores: (min: 11, avg: 147.34, max: 489)
#
# Run: 418, exploration: 0.05, score: 28
# Scores: (min: 11, avg: 145.67, max: 489)
#
# Run: 419, exploration: 0.05, score: 193
# Scores: (min: 11, avg: 146.32, max: 489)
#
# Run: 420, exploration: 0.05, score: 236
# Scores: (min: 11, avg: 147.74, max: 489)
#
# Run: 421, exploration: 0.05, score: 168
# Scores: (min: 11, avg: 147.05, max: 489)
#
# Run: 422, exploration: 0.05, score: 107
# Scores: (min: 11, avg: 145.39, max: 489)
#
# Run: 423, exploration: 0.05, score: 86
# Scores: (min: 11, avg: 142.33, max: 489)
#
# Run: 424, exploration: 0.05, score: 105
# Scores: (min: 11, avg: 141.82, max: 489)
#
# Run: 425, exploration: 0.05, score: 52
# Scores: (min: 11, avg: 140.95, max: 489)
#
# Run: 426, exploration: 0.05, score: 140
# Scores: (min: 11, avg: 140.76, max: 489)
#
# Run: 427, exploration: 0.05, score: 137
# Scores: (min: 11, avg: 140.64, max: 489)
#
# Run: 428, exploration: 0.05, score: 101
# Scores: (min: 11, avg: 138.18, max: 489)
#
# Run: 429, exploration: 0.05, score: 123
# Scores: (min: 11, avg: 138.62, max: 489)
#
# Run: 430, exploration: 0.05, score: 119
# Scores: (min: 11, avg: 139.38, max: 489)
#
# Run: 431, exploration: 0.05, score: 288
# Scores: (min: 11, avg: 141.23, max: 489)
#
# Run: 432, exploration: 0.05, score: 485
# Scores: (min: 11, avg: 143.65, max: 489)
#
# Run: 433, exploration: 0.05, score: 161
# Scores: (min: 11, avg: 144.33, max: 489)
#
# Run: 434, exploration: 0.05, score: 99
# Scores: (min: 11, avg: 144.6, max: 489)
#
# Run: 435, exploration: 0.05, score: 292
# Scores: (min: 11, avg: 146.57, max: 489)
#
# Run: 436, exploration: 0.05, score: 310
# Scores: (min: 11, avg: 146.66, max: 489)
#
# Run: 437, exploration: 0.05, score: 30
# Scores: (min: 11, avg: 143.41, max: 489)
#
# Run: 438, exploration: 0.05, score: 52
# Scores: (min: 11, avg: 142.99, max: 489)
#
# Run: 439, exploration: 0.05, score: 159
# Scores: (min: 11, avg: 142.9, max: 489)
#
# Run: 440, exploration: 0.05, score: 132
# Scores: (min: 11, avg: 141.47, max: 489)
#
# Run: 441, exploration: 0.05, score: 452
# Scores: (min: 11, avg: 144.56, max: 489)
#
# Run: 442, exploration: 0.05, score: 101
# Scores: (min: 11, avg: 143.89, max: 489)
#
# Run: 443, exploration: 0.05, score: 393
# Scores: (min: 11, avg: 145.68, max: 489)
#
# Run: 444, exploration: 0.05, score: 157
# Scores: (min: 11, avg: 145.99, max: 489)
#
# Run: 445, exploration: 0.05, score: 106
# Scores: (min: 11, avg: 145.4, max: 489)
#
# Run: 446, exploration: 0.05, score: 237
# Scores: (min: 11, avg: 146.63, max: 489)
#
# Run: 447, exploration: 0.05, score: 122
# Scores: (min: 11, avg: 145.04, max: 489)
#
# Run: 448, exploration: 0.05, score: 372
# Scores: (min: 11, avg: 147.77, max: 489)
#
# Run: 449, exploration: 0.05, score: 41
# Scores: (min: 11, avg: 147.01, max: 489)
#
# Run: 450, exploration: 0.05, score: 15
# Scores: (min: 11, avg: 146.15, max: 489)
#
# Run: 451, exploration: 0.05, score: 116
# Scores: (min: 11, avg: 144.42, max: 489)
#
# Run: 452, exploration: 0.05, score: 104
# Scores: (min: 11, avg: 144.25, max: 489)
#
# Run: 453, exploration: 0.05, score: 115
# Scores: (min: 11, avg: 143.93, max: 489)
#
# Run: 454, exploration: 0.05, score: 138
# Scores: (min: 11, avg: 143.79, max: 489)
#
# Run: 455, exploration: 0.05, score: 14
# Scores: (min: 11, avg: 142.84, max: 489)
#
# Run: 456, exploration: 0.05, score: 11
# Scores: (min: 11, avg: 141.79, max: 489)
#
# Run: 457, exploration: 0.05, score: 163
# Scores: (min: 11, avg: 142.33, max: 489)
#
# Run: 458, exploration: 0.05, score: 146
# Scores: (min: 11, avg: 142.82, max: 489)
#
# Run: 459, exploration: 0.05, score: 229
# Scores: (min: 11, avg: 140.43, max: 489)
#
# Run: 460, exploration: 0.05, score: 119
# Scores: (min: 11, avg: 140.4, max: 489)
#
# Run: 461, exploration: 0.05, score: 111
# Scores: (min: 11, avg: 141.21, max: 489)
#
# Run: 462, exploration: 0.05, score: 112
# Scores: (min: 11, avg: 142.22, max: 489)
#
# Run: 463, exploration: 0.05, score: 344
# Scores: (min: 11, avg: 145.52, max: 489)
#
# Run: 464, exploration: 0.05, score: 128
# Scores: (min: 11, avg: 145.45, max: 489)
#
# Run: 465, exploration: 0.05, score: 113
# Scores: (min: 11, avg: 144.17, max: 489)
#
# Run: 466, exploration: 0.05, score: 500
# Scores: (min: 11, avg: 148.33, max: 500)
#
# Run: 467, exploration: 0.05, score: 219
# Scores: (min: 11, avg: 149.68, max: 500)
#
# Run: 468, exploration: 0.05, score: 174
# Scores: (min: 11, avg: 150.99, max: 500)
#
# Run: 469, exploration: 0.05, score: 354
# Scores: (min: 11, avg: 153.91, max: 500)
#
# Run: 470, exploration: 0.05, score: 443
# Scores: (min: 11, avg: 158.12, max: 500)
#
# Run: 471, exploration: 0.05, score: 430
# Scores: (min: 11, avg: 161.34, max: 500)
#
# Run: 472, exploration: 0.05, score: 107
# Scores: (min: 11, avg: 161.51, max: 500)
#
# Run: 473, exploration: 0.05, score: 27
# Scores: (min: 11, avg: 160.72, max: 500)
#
# Run: 474, exploration: 0.05, score: 96
# Scores: (min: 11, avg: 160.44, max: 500)
#
# Run: 475, exploration: 0.05, score: 417
# Scores: (min: 11, avg: 163.53, max: 500)
#
# Run: 476, exploration: 0.05, score: 410
# Scores: (min: 11, avg: 166.54, max: 500)
#
# Run: 477, exploration: 0.05, score: 112
# Scores: (min: 11, avg: 166.7, max: 500)
#
# Run: 478, exploration: 0.05, score: 95
# Scores: (min: 11, avg: 166.03, max: 500)
#
# Run: 479, exploration: 0.05, score: 118
# Scores: (min: 11, avg: 166.19, max: 500)
#
# Run: 480, exploration: 0.05, score: 174
# Scores: (min: 11, avg: 166.76, max: 500)
#
# Run: 481, exploration: 0.05, score: 45
# Scores: (min: 11, avg: 166.75, max: 500)
#
# Run: 482, exploration: 0.05, score: 16
# Scores: (min: 11, avg: 166.43, max: 500)
#
# Run: 483, exploration: 0.05, score: 25
# Scores: (min: 11, avg: 165.6, max: 500)
#
# Run: 484, exploration: 0.05, score: 29
# Scores: (min: 11, avg: 165.35, max: 500)
#
# Run: 485, exploration: 0.05, score: 23
# Scores: (min: 11, avg: 163.29, max: 500)
#
# Run: 486, exploration: 0.05, score: 64
# Scores: (min: 11, avg: 161.7, max: 500)
#
# Run: 487, exploration: 0.05, score: 80
# Scores: (min: 11, avg: 161.58, max: 500)
#
# Run: 488, exploration: 0.05, score: 357
# Scores: (min: 11, avg: 163.95, max: 500)
#
# Run: 489, exploration: 0.05, score: 46
# Scores: (min: 11, avg: 163.16, max: 500)
#
# Run: 490, exploration: 0.05, score: 98
# Scores: (min: 11, avg: 163.06, max: 500)
#
# Run: 491, exploration: 0.05, score: 98
# Scores: (min: 11, avg: 162.72, max: 500)
# Run: 492, exploration: 0.05, score: 287
# Scores: (min: 11, avg: 164.7, max: 500)
#
# Run: 493, exploration: 0.05, score: 500
# Scores: (min: 11, avg: 167.85, max: 500)
#
# Run: 494, exploration: 0.05, score: 95
# Scores: (min: 11, avg: 168.51, max: 500)
#
# Run: 495, exploration: 0.05, score: 107
# Scores: (min: 11, avg: 168.1, max: 500)
#
# Run: 496, exploration: 0.05, score: 113
# Scores: (min: 11, avg: 166.7, max: 500)
#
# Run: 497, exploration: 0.05, score: 112
# Scores: (min: 11, avg: 166.12, max: 500)
#
# Run: 498, exploration: 0.05, score: 239
# Scores: (min: 11, avg: 167.08, max: 500)
#
# Run: 499, exploration: 0.05, score: 40
# Scores: (min: 11, avg: 166.63, max: 500)
#
# Run: 500, exploration: 0.05, score: 161
# Scores: (min: 11, avg: 166.44, max: 500)
#
# Run: 501, exploration: 0.05, score: 108
# Scores: (min: 11, avg: 166.37, max: 500)
#
# Run: 502, exploration: 0.05, score: 277
# Scores: (min: 11, avg: 168.36, max: 500)
#
# Run: 503, exploration: 0.05, score: 77
# Scores: (min: 11, avg: 167.04, max: 500)
#
# Run: 504, exploration: 0.05, score: 118
# Scores: (min: 11, avg: 164.15, max: 500)
#
# Run: 505, exploration: 0.05, score: 28
# Scores: (min: 11, avg: 159.54, max: 500)
#
# Run: 506, exploration: 0.05, score: 15
# Scores: (min: 11, avg: 157.79, max: 500)
#
# Run: 507, exploration: 0.05, score: 25
# Scores: (min: 11, avg: 156.59, max: 500)
#
# Run: 508, exploration: 0.05, score: 96
# Scores: (min: 11, avg: 157.44, max: 500)
#
# Run: 509, exploration: 0.05, score: 72
# Scores: (min: 11, avg: 155.99, max: 500)
#
# Run: 510, exploration: 0.05, score: 279
# Scores: (min: 11, avg: 158.51, max: 500)
#
# Run: 511, exploration: 0.05, score: 133
# Scores: (min: 11, avg: 159.41, max: 500)
#
# Run: 512, exploration: 0.05, score: 393
# Scores: (min: 11, avg: 162.36, max: 500)
#
# Run: 513, exploration: 0.05, score: 452
# Scores: (min: 11, avg: 165.37, max: 500)
#
# Run: 514, exploration: 0.05, score: 278
# Scores: (min: 11, avg: 167.25, max: 500)
#
# Run: 515, exploration: 0.05, score: 132
# Scores: (min: 11, avg: 167.44, max: 500)
#
# Run: 516, exploration: 0.05, score: 90
# Scores: (min: 11, avg: 165.82, max: 500)
#
# Run: 517, exploration: 0.05, score: 145
# Scores: (min: 11, avg: 164.91, max: 500)
#
# Run: 518, exploration: 0.05, score: 22
# Scores: (min: 11, avg: 164.85, max: 500)
#
# Run: 519, exploration: 0.05, score: 98
# Scores: (min: 11, avg: 163.9, max: 500)
#
# Run: 520, exploration: 0.05, score: 44
# Scores: (min: 11, avg: 161.98, max: 500)
#
# Run: 521, exploration: 0.05, score: 500
# Scores: (min: 11, avg: 165.3, max: 500)
#
# Run: 522, exploration: 0.05, score: 100
# Scores: (min: 11, avg: 165.23, max: 500)
#
# Run: 523, exploration: 0.05, score: 102
# Scores: (min: 11, avg: 165.39, max: 500)
#
# Run: 524, exploration: 0.05, score: 360
# Scores: (min: 11, avg: 167.94, max: 500)
#
# Run: 525, exploration: 0.05, score: 157
# Scores: (min: 11, avg: 168.99, max: 500)
#
# Run: 526, exploration: 0.05, score: 114
# Scores: (min: 11, avg: 168.73, max: 500)
#
# Run: 527, exploration: 0.05, score: 125
# Scores: (min: 11, avg: 168.61, max: 500)
#
# Run: 528, exploration: 0.05, score: 16
# Scores: (min: 11, avg: 167.76, max: 500)
#
# Run: 529, exploration: 0.05, score: 44
# Scores: (min: 11, avg: 166.97, max: 500)
#
# Run: 530, exploration: 0.05, score: 66
# Scores: (min: 11, avg: 166.44, max: 500)
#
# Run: 531, exploration: 0.05, score: 103
# Scores: (min: 11, avg: 164.59, max: 500)
#
# Run: 532, exploration: 0.05, score: 100
# Scores: (min: 11, avg: 160.74, max: 500)
#
# Run: 533, exploration: 0.05, score: 99
# Scores: (min: 11, avg: 160.12, max: 500)
#
# Run: 534, exploration: 0.05, score: 34
# Scores: (min: 11, avg: 159.47, max: 500)
#
# Run: 535, exploration: 0.05, score: 12
# Scores: (min: 11, avg: 156.67, max: 500)
#
# Run: 536, exploration: 0.05, score: 72
# Scores: (min: 11, avg: 154.29, max: 500)
#
# Run: 537, exploration: 0.05, score: 90
# Scores: (min: 11, avg: 154.89, max: 500)
#
# Run: 538, exploration: 0.05, score: 69
# Scores: (min: 11, avg: 155.06, max: 500)
#
# Run: 539, exploration: 0.05, score: 41
# Scores: (min: 11, avg: 153.88, max: 500)
#
# Run: 540, exploration: 0.05, score: 28
# Scores: (min: 11, avg: 152.84, max: 500)
#
# Run: 541, exploration: 0.05, score: 43
# Scores: (min: 11, avg: 148.75, max: 500)
#
# Run: 542, exploration: 0.05, score: 88
# Scores: (min: 11, avg: 148.62, max: 500)
#
# Run: 543, exploration: 0.05, score: 95
# Scores: (min: 11, avg: 145.64, max: 500)
#
# Run: 544, exploration: 0.05, score: 25
# Scores: (min: 11, avg: 144.32, max: 500)
#
# Run: 545, exploration: 0.05, score: 65
# Scores: (min: 11, avg: 143.91, max: 500)
#
# Run: 546, exploration: 0.05, score: 102
# Scores: (min: 11, avg: 142.56, max: 500)
#
# Run: 547, exploration: 0.05, score: 78
# Scores: (min: 11, avg: 142.12, max: 500)
#
# Run: 548, exploration: 0.05, score: 79
# Scores: (min: 11, avg: 139.19, max: 500)
#
# Run: 549, exploration: 0.05, score: 92
# Scores: (min: 11, avg: 139.7, max: 500)
#
# Run: 550, exploration: 0.05, score: 106
# Scores: (min: 11, avg: 140.61, max: 500)
#
# Run: 551, exploration: 0.05, score: 93
# Scores: (min: 11, avg: 140.38, max: 500)
#
# Run: 552, exploration: 0.05, score: 90
# Scores: (min: 11, avg: 140.24, max: 500)
#
# Run: 553, exploration: 0.05, score: 51
# Scores: (min: 11, avg: 139.6, max: 500)
#
# Run: 554, exploration: 0.05, score: 84
# Scores: (min: 11, avg: 139.06, max: 500)
#
# Run: 555, exploration: 0.05, score: 71
# Scores: (min: 11, avg: 139.63, max: 500)
#
# Run: 556, exploration: 0.05, score: 45
# Scores: (min: 12, avg: 139.97, max: 500)
#
# Run: 557, exploration: 0.05, score: 30
# Scores: (min: 12, avg: 138.64, max: 500)
#
# Run: 558, exploration: 0.05, score: 28
# Scores: (min: 12, avg: 137.46, max: 500)
#
# Run: 559, exploration: 0.05, score: 20
# Scores: (min: 12, avg: 135.37, max: 500)
#
# Run: 560, exploration: 0.05, score: 193
# Scores: (min: 12, avg: 136.11, max: 500)
#
# Run: 561, exploration: 0.05, score: 31
# Scores: (min: 12, avg: 135.31, max: 500)
#
# Run: 562, exploration: 0.05, score: 45
# Scores: (min: 12, avg: 134.64, max: 500)
#
# Run: 563, exploration: 0.05, score: 23
# Scores: (min: 12, avg: 131.43, max: 500)
#
# Run: 564, exploration: 0.05, score: 80
# Scores: (min: 12, avg: 130.95, max: 500)
#
# Run: 565, exploration: 0.05, score: 57
# Scores: (min: 12, avg: 130.39, max: 500)
#
# Run: 566, exploration: 0.05, score: 57
# Scores: (min: 12, avg: 125.96, max: 500)
#
# Run: 567, exploration: 0.05, score: 25
# Scores: (min: 12, avg: 124.02, max: 500)
#
# Run: 568, exploration: 0.05, score: 260
# Scores: (min: 12, avg: 124.88, max: 500)
#
# Run: 569, exploration: 0.05, score: 98
# Scores: (min: 12, avg: 122.32, max: 500)
#
# Run: 570, exploration: 0.05, score: 102
# Scores: (min: 12, avg: 118.91, max: 500)
#
# Run: 571, exploration: 0.05, score: 128
# Scores: (min: 12, avg: 115.89, max: 500)
#
# Run: 572, exploration: 0.05, score: 147
# Scores: (min: 12, avg: 116.29, max: 500)
#
# Run: 573, exploration: 0.05, score: 183
# Scores: (min: 12, avg: 117.85, max: 500)
#
# Run: 574, exploration: 0.05, score: 208
# Scores: (min: 12, avg: 118.97, max: 500)
#
# ...
# Scores: (min: 8, avg: 24.38, max: 179)
#
# Run: 1270, exploration: 0.05, score: 20
# Scores: (min: 8, avg: 24.46, max: 179)
#
# Run: 1271, exploration: 0.05, score: 11
# Scores: (min: 8, avg: 24.47, max: 179)
#
# Run: 1272, exploration: 0.05, score: 14
# Scores: (min: 8, avg: 24.51, max: 179)
#
# Run: 1273, exploration: 0.05, score: 22
# Scores: (min: 8, avg: 24.65, max: 179)
#
# Run: 1274, exploration: 0.05, score: 16
# Scores: (min: 8, avg: 24.72, max: 179)
#
# Run: 1275, exploration: 0.05, score: 31
# Scores: (min: 8, avg: 24.93, max: 179)
#
# Run: 1276, exploration: 0.05, score: 12
# Scores: (min: 8, avg: 24.96, max: 179)
#
# Run: 1277, exploration: 0.05, score: 19
# Scores: (min: 8, avg: 25.06, max: 179)
#
# Run: 1278, exploration: 0.05, score: 16
# Scores: (min: 8, avg: 25.13, max: 179)
#
# Run: 1279, exploration: 0.05, score: 19
# Scores: (min: 8, avg: 25.23, max: 179)
#
# Run: 1280, exploration: 0.05, score: 11
# Scores: (min: 8, avg: 25.24, max: 179)
#
# Run: 1281, exploration: 0.05, score: 17
# Scores: (min: 8, avg: 25.32, max: 179)
#
# Run: 1282, exploration: 0.05, score: 12
# Scores: (min: 8, avg: 25.35, max: 179)
#
# Run: 1283, exploration: 0.05, score: 50
# Scores: (min: 8, avg: 25.75, max: 179)
#
# Run: 1284, exploration: 0.05, score: 21
# Scores: (min: 8, avg: 25.86, max: 179)
#
# Run: 1285, exploration: 0.05, score: 18
# Scores: (min: 8, avg: 25.95, max: 179)
#
# Run: 1286, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 25.95, max: 179)
#
# Run: 1287, exploration: 0.05, score: 11
# Scores: (min: 8, avg: 25.97, max: 179)
#
# Run: 1288, exploration: 0.05, score: 58
# Scores: (min: 8, avg: 26.45, max: 179)
#
# Run: 1289, exploration: 0.05, score: 27
# Scores: (min: 8, avg: 26.63, max: 179)
#
# Run: 1290, exploration: 0.05, score: 12
# Scores: (min: 8, avg: 26.66, max: 179)
#
# Run: 1291, exploration: 0.05, score: 39
# Scores: (min: 8, avg: 26.96, max: 179)
#
# Run: 1292, exploration: 0.05, score: 15
# Scores: (min: 8, avg: 27, max: 179)
#
# Run: 1293, exploration: 0.05, score: 56
# Scores: (min: 8, avg: 27.48, max: 179)
#
# Run: 1294, exploration: 0.05, score: 12
# Scores: (min: 8, avg: 27.47, max: 179)
#
# Run: 1295, exploration: 0.05, score: 14
# Scores: (min: 8, avg: 27.52, max: 179)
#
# Run: 1296, exploration: 0.05, score: 16
# Scores: (min: 9, avg: 27.6, max: 179)
#
# Run: 1297, exploration: 0.05, score: 13
# Scores: (min: 9, avg: 27.63, max: 179)
#
# Run: 1298, exploration: 0.05, score: 18
# Scores: (min: 9, avg: 26.9, max: 179)
#
# Run: 1299, exploration: 0.05, score: 19
# Scores: (min: 9, avg: 25.3, max: 151)
#
# Run: 1300, exploration: 0.05, score: 36
# Scores: (min: 9, avg: 24.98, max: 151)
#
# Run: 1301, exploration: 0.05, score: 9
# Scores: (min: 9, avg: 24.67, max: 151)
#
# Run: 1302, exploration: 0.05, score: 23
# Scores: (min: 9, avg: 24.39, max: 151)
#
# Run: 1303, exploration: 0.05, score: 22
# Scores: (min: 9, avg: 24.14, max: 151)
#
# Run: 1304, exploration: 0.05, score: 101
# Scores: (min: 9, avg: 24.79, max: 151)
#
# Run: 1305, exploration: 0.05, score: 95
# Scores: (min: 9, avg: 25.34, max: 151)
#
# Run: 1306, exploration: 0.05, score: 8
# Scores: (min: 8, avg: 25.09, max: 151)
#
# Run: 1307, exploration: 0.05, score: 74
# Scores: (min: 8, avg: 25.49, max: 151)
#
# Run: 1308, exploration: 0.05, score: 13
# Scores: (min: 8, avg: 25.26, max: 151)
#
# Run: 1309, exploration: 0.05, score: 22
# Scores: (min: 8, avg: 25.24, max: 151)
#
# Run: 1310, exploration: 0.05, score: 12
# Scores: (min: 8, avg: 25.03, max: 151)
# Run: 1311, exploration: 0.05, score: 18
# Scores: (min: 8, avg: 24.99, max: 151)
#
# Run: 1312, exploration: 0.05, score: 18
# Scores: (min: 8, avg: 25.01, max: 151)
#
# Run: 1313, exploration: 0.05, score: 18
# Scores: (min: 8, avg: 25.04, max: 151)
#
# Run: 1314, exploration: 0.05, score: 19
# Scores: (min: 8, avg: 25.07, max: 151)
#
# Run: 1315, exploration: 0.05, score: 13
# Scores: (min: 8, avg: 24.95, max: 151)
#
# Run: 1316, exploration: 0.05, score: 31
# Scores: (min: 8, avg: 25.06, max: 151)
#
# Run: 1317, exploration: 0.05, score: 206
# Scores: (min: 8, avg: 26.84, max: 206)
#
# Run: 1318, exploration: 0.05, score: 27
# Scores: (min: 8, avg: 26.86, max: 206)
#
# Run: 1319, exploration: 0.05, score: 21
# Scores: (min: 8, avg: 26.77, max: 206)
#
# Run: 1320, exploration: 0.05, score: 17
# Scores: (min: 8, avg: 26.69, max: 206)
#
# Run: 1321, exploration: 0.05, score: 16
# Scores: (min: 8, avg: 26.64, max: 206)
#
# Run: 1322, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 26.55, max: 206)
#
# Run: 1323, exploration: 0.05, score: 25
# Scores: (min: 8, avg: 26.59, max: 206)
#
# Run: 1324, exploration: 0.05, score: 15
# Scores: (min: 8, avg: 26.24, max: 206)
#
# Run: 1325, exploration: 0.05, score: 35
# Scores: (min: 8, avg: 25.71, max: 206)
#
# Run: 1326, exploration: 0.05, score: 85
# Scores: (min: 8, avg: 26.31, max: 206)
#
# Run: 1327, exploration: 0.05, score: 128
# Scores: (min: 8, avg: 27.35, max: 206)
#
# Run: 1328, exploration: 0.05, score: 13
# Scores: (min: 8, avg: 27.27, max: 206)
#
# Run: 1329, exploration: 0.05, score: 13
# Scores: (min: 8, avg: 27.11, max: 206)
#
# Run: 1330, exploration: 0.05, score: 17
# Scores: (min: 8, avg: 26.94, max: 206)
#
# Run: 1331, exploration: 0.05, score: 12
# Scores: (min: 8, avg: 26.73, max: 206)
#
# Run: 1332, exploration: 0.05, score: 58
# Scores: (min: 8, avg: 27.04, max: 206)
#
# Run: 1333, exploration: 0.05, score: 18
# Scores: (min: 8, avg: 27.03, max: 206)
#
# Run: 1334, exploration: 0.05, score: 124
# Scores: (min: 8, avg: 28.03, max: 206)
#
# Run: 1335, exploration: 0.05, score: 13
# Scores: (min: 8, avg: 27.85, max: 206)
#
# Run: 1336, exploration: 0.05, score: 11
# Scores: (min: 8, avg: 26.8, max: 206)
#
# Run: 1337, exploration: 0.05, score: 36
# Scores: (min: 8, avg: 26.97, max: 206)
#
# Run: 1338, exploration: 0.05, score: 13
# Scores: (min: 8, avg: 27.01, max: 206)
#
# Run: 1339, exploration: 0.05, score: 21
# Scores: (min: 8, avg: 27.12, max: 206)
#
# Run: 1340, exploration: 0.05, score: 20
# Scores: (min: 8, avg: 27.22, max: 206)
#
# Run: 1341, exploration: 0.05, score: 94
# Scores: (min: 8, avg: 27.96, max: 206)
#
# Run: 1342, exploration: 0.05, score: 13
# Scores: (min: 8, avg: 27.95, max: 206)
#
# Run: 1343, exploration: 0.05, score: 14
# Scores: (min: 8, avg: 27.85, max: 206)
#
# Run: 1344, exploration: 0.05, score: 20
# Scores: (min: 8, avg: 27.95, max: 206)
#
# Run: 1345, exploration: 0.05, score: 39
# Scores: (min: 8, avg: 28.24, max: 206)
#
# Run: 1346, exploration: 0.05, score: 90
# Scores: (min: 8, avg: 29.02, max: 206)
#
# Run: 1347, exploration: 0.05, score: 46
# Scores: (min: 8, avg: 29.26, max: 206)
#
# Run: 1348, exploration: 0.05, score: 45
# Scores: (min: 8, avg: 29.4, max: 206)
#
# Run: 1349, exploration: 0.05, score: 114
# Scores: (min: 8, avg: 29.03, max: 206)
#
# Run: 1350, exploration: 0.05, score: 139
# Scores: (min: 8, avg: 30.27, max: 206)
#
# Run: 1351, exploration: 0.05, score: 57
# Scores: (min: 8, avg: 30.62, max: 206)
#
# Run: 1352, exploration: 0.05, score: 70
# Scores: (min: 8, avg: 31.2, max: 206)
#
# Run: 1353, exploration: 0.05, score: 18
# Scores: (min: 8, avg: 31.27, max: 206)
#
# Run: 1354, exploration: 0.05, score: 13
# Scores: (min: 8, avg: 31.23, max: 206)
#
# Run: 1355, exploration: 0.05, score: 35
# Scores: (min: 8, avg: 31.47, max: 206)
#
# Run: 1356, exploration: 0.05, score: 30
# Scores: (min: 8, avg: 31.65, max: 206)
#
# Run: 1357, exploration: 0.05, score: 19
# Scores: (min: 8, avg: 31.72, max: 206)
#
# Run: 1358, exploration: 0.05, score: 21
# Scores: (min: 8, avg: 31.75, max: 206)
#
# Run: 1359, exploration: 0.05, score: 23
# Scores: (min: 8, avg: 31.68, max: 206)
#
# Run: 1360, exploration: 0.05, score: 120
# Scores: (min: 8, avg: 32.74, max: 206)
#
# Run: 1361, exploration: 0.05, score: 18
# Scores: (min: 8, avg: 32.79, max: 206)
#
# Run: 1362, exploration: 0.05, score: 35
# Scores: (min: 8, avg: 32.98, max: 206)
#
# Run: 1363, exploration: 0.05, score: 17
# Scores: (min: 8, avg: 33.04, max: 206)
#
# Run: 1364, exploration: 0.05, score: 46
# Scores: (min: 8, avg: 33.33, max: 206)
#
# Run: 1365, exploration: 0.05, score: 72
# Scores: (min: 8, avg: 33.89, max: 206)
#
# Run: 1366, exploration: 0.05, score: 110
# Scores: (min: 8, avg: 34.83, max: 206)
#
# Run: 1367, exploration: 0.05, score: 86
# Scores: (min: 8, avg: 35.54, max: 206)
#
# Run: 1368, exploration: 0.05, score: 86
# Scores: (min: 8, avg: 36.26, max: 206)
#
# Run: 1369, exploration: 0.05, score: 138
# Scores: (min: 8, avg: 37.43, max: 206)
#
# Run: 1370, exploration: 0.05, score: 97
# Scores: (min: 8, avg: 38.2, max: 206)
#
# Run: 1371, exploration: 0.05, score: 49
# Scores: (min: 8, avg: 38.58, max: 206)
#
# Run: 1372, exploration: 0.05, score: 166
# Scores: (min: 8, avg: 40.1, max: 206)
#
# Run: 1373, exploration: 0.05, score: 77
# Scores: (min: 8, avg: 40.65, max: 206)
#
# Run: 1374, exploration: 0.05, score: 78
# Scores: (min: 8, avg: 41.27, max: 206)
#
# Run: 1375, exploration: 0.05, score: 125
# Scores: (min: 8, avg: 42.21, max: 206)
#
# Run: 1376, exploration: 0.05, score: 74
# Scores: (min: 8, avg: 42.83, max: 206)
#
# Run: 1377, exploration: 0.05, score: 75
# Scores: (min: 8, avg: 43.39, max: 206)
#
# Run: 1378, exploration: 0.05, score: 26
# Scores: (min: 8, avg: 43.49, max: 206)
#
# Run: 1379, exploration: 0.05, score: 29
# Scores: (min: 8, avg: 43.59, max: 206)
#
# Run: 1380, exploration: 0.05, score: 106
# Scores: (min: 8, avg: 44.54, max: 206)
#
# Run: 1381, exploration: 0.05, score: 38
# Scores: (min: 8, avg: 44.75, max: 206)
#
# Run: 1382, exploration: 0.05, score: 11
# Scores: (min: 8, avg: 44.74, max: 206)
#
# Run: 1383, exploration: 0.05, score: 177
# Scores: (min: 8, avg: 46.01, max: 206)
#
# Run: 1384, exploration: 0.05, score: 172
# Scores: (min: 8, avg: 47.52, max: 206)
#
# Run: 1385, exploration: 0.05, score: 68
# Scores: (min: 8, avg: 48.02, max: 206)
#
# Run: 1386, exploration: 0.05, score: 106
# Scores: (min: 8, avg: 48.98, max: 206)
#
# Run: 1387, exploration: 0.05, score: 135
# Scores: (min: 8, avg: 50.22, max: 206)
#
# Run: 1388, exploration: 0.05, score: 210
# Scores: (min: 8, avg: 51.74, max: 210)
#
# Run: 1389, exploration: 0.05, score: 165
# Scores: (min: 8, avg: 53.12, max: 210)
#
# Run: 1390, exploration: 0.05, score: 168
# Scores: (min: 8, avg: 54.68, max: 210)
#
# Run: 1391, exploration: 0.05, score: 271
# Scores: (min: 8, avg: 57, max: 271)
#
# Run: 1392, exploration: 0.05, score: 389
# Scores: (min: 8, avg: 60.74, max: 389)
#
# Run: 1393, exploration: 0.05, score: 356
# Scores: (min: 8, avg: 63.74, max: 389)
#
# Run: 1394, exploration: 0.05, score: 471
# Scores: (min: 8, avg: 68.33, max: 471)
#
# Run: 1395, exploration: 0.05, score: 184
# Scores: (min: 8, avg: 70.03, max: 471)
#
# Run: 1396, exploration: 0.05, score: 500
# Scores: (min: 8, avg: 74.87, max: 500)
#
# Run: 1397, exploration: 0.05, score: 500
# Scores: (min: 8, avg: 79.74, max: 500)
#
# Run: 1398, exploration: 0.05, score: 325
# Scores: (min: 8, avg: 82.81, max: 500)
#
# Run: 1399, exploration: 0.05, score: 500
# Scores: (min: 8, avg: 87.62, max: 500)
#
# Run: 1400, exploration: 0.05, score: 500
# Scores: (min: 8, avg: 92.26, max: 500)
#
# Run: 1401, exploration: 0.05, score: 163
# Scores: (min: 8, avg: 93.8, max: 500)
#
# Run: 1402, exploration: 0.05, score: 221
# Scores: (min: 8, avg: 95.78, max: 500)
#
# Run: 1403, exploration: 0.05, score: 500
# Scores: (min: 8, avg: 100.56, max: 500)
#
# Run: 1404, exploration: 0.05, score: 152
# Scores: (min: 8, avg: 101.07, max: 500)
#
# Run: 1405, exploration: 0.05, score: 120
# Scores: (min: 8, avg: 101.32, max: 500)
#
# Run: 1406, exploration: 0.05, score: 43
# Scores: (min: 10, avg: 101.67, max: 500)
#
# Run: 1407, exploration: 0.05, score: 500
# Scores: (min: 10, avg: 105.93, max: 500)
#
# Run: 1408, exploration: 0.05, score: 172
# Scores: (min: 10, avg: 107.52, max: 500)
#
# Run: 1409, exploration: 0.05, score: 261
# Scores: (min: 10, avg: 109.91, max: 500)
#
# Run: 1410, exploration: 0.05, score: 239
# Scores: (min: 10, avg: 112.18, max: 500)
#
# Run: 1411, exploration: 0.05, score: 500
# Scores: (min: 10, avg: 117, max: 500)
#
# Run: 1412, exploration: 0.05, score: 377
# Scores: (min: 10, avg: 120.59, max: 500)
# Run: 1413, exploration: 0.05, score: 173
# Scores: (min: 10, avg: 122.14, max: 500)
#
# Run: 1414, exploration: 0.05, score: 131
# Scores: (min: 10, avg: 123.26, max: 500)
#
# Run: 1415, exploration: 0.05, score: 209
# Scores: (min: 10, avg: 125.22, max: 500)
#
# Run: 1416, exploration: 0.05, score: 217
# Scores: (min: 10, avg: 127.08, max: 500)
#
# Run: 1417, exploration: 0.05, score: 309
# Scores: (min: 10, avg: 128.11, max: 500)
#
# Run: 1418, exploration: 0.05, score: 151
# Scores: (min: 10, avg: 129.35, max: 500)
#
# Run: 1419, exploration: 0.05, score: 208
# Scores: (min: 10, avg: 131.22, max: 500)
#
# Run: 1420, exploration: 0.05, score: 134
# Scores: (min: 10, avg: 132.39, max: 500)
#
# Run: 1421, exploration: 0.05, score: 113
# Scores: (min: 10, avg: 133.36, max: 500)
#
# Run: 1422, exploration: 0.05, score: 415
# Scores: (min: 11, avg: 137.41, max: 500)
#
# Run: 1423, exploration: 0.05, score: 499
# Scores: (min: 11, avg: 142.15, max: 500)
#
# Run: 1424, exploration: 0.05, score: 153
# Scores: (min: 11, avg: 143.53, max: 500)
#
# Run: 1425, exploration: 0.05, score: 225
# Scores: (min: 11, avg: 145.43, max: 500)
#
# Run: 1426, exploration: 0.05, score: 500
# Scores: (min: 11, avg: 149.58, max: 500)
#
# Run: 1427, exploration: 0.05, score: 147
# Scores: (min: 11, avg: 149.77, max: 500)
#
# Run: 1428, exploration: 0.05, score: 170
# Scores: (min: 11, avg: 151.34, max: 500)
#
# Run: 1429, exploration: 0.05, score: 500
# Scores: (min: 11, avg: 156.21, max: 500)
#
# Run: 1430, exploration: 0.05, score: 179
# Scores: (min: 11, avg: 157.83, max: 500)
#
# Run: 1431, exploration: 0.05, score: 182
# Scores: (min: 11, avg: 159.53, max: 500)
#
# Run: 1432, exploration: 0.05, score: 195
# Scores: (min: 11, avg: 160.9, max: 500)
#
# Run: 1433, exploration: 0.05, score: 102
# Scores: (min: 11, avg: 161.74, max: 500)
#
# Run: 1434, exploration: 0.05, score: 417
# Scores: (min: 11, avg: 164.67, max: 500)
#
# Run: 1435, exploration: 0.05, score: 125
# Scores: (min: 11, avg: 165.79, max: 500)
#
# Run: 1436, exploration: 0.05, score: 53
# Scores: (min: 11, avg: 166.21, max: 500)
#
# Run: 1437, exploration: 0.05, score: 202
# Scores: (min: 11, avg: 167.87, max: 500)
#
# Run: 1438, exploration: 0.05, score: 134
# Scores: (min: 11, avg: 169.08, max: 500)
#
# Run: 1439, exploration: 0.05, score: 268
# Scores: (min: 11, avg: 171.55, max: 500)
#
# Run: 1440, exploration: 0.05, score: 371
# Scores: (min: 11, avg: 175.06, max: 500)
#
# Run: 1441, exploration: 0.05, score: 142
# Scores: (min: 11, avg: 175.54, max: 500)
#
# Run: 1442, exploration: 0.05, score: 185
# Scores: (min: 11, avg: 177.26, max: 500)
#
# Run: 1443, exploration: 0.05, score: 270
# Scores: (min: 11, avg: 179.82, max: 500)
#
# Run: 1444, exploration: 0.05, score: 175
# Scores: (min: 11, avg: 181.37, max: 500)
#
# Run: 1445, exploration: 0.05, score: 205
# Scores: (min: 11, avg: 183.03, max: 500)
#
# Run: 1446, exploration: 0.05, score: 226
# Scores: (min: 11, avg: 184.39, max: 500)
#
# Run: 1447, exploration: 0.05, score: 332
# Scores: (min: 11, avg: 187.25, max: 500)
#
# Run: 1448, exploration: 0.05, score: 155
# Scores: (min: 11, avg: 188.35, max: 500)
#
# Run: 1449, exploration: 0.05, score: 129
# Scores: (min: 11, avg: 188.5, max: 500)
#
# Run: 1450, exploration: 0.05, score: 265
# Scores: (min: 11, avg: 189.76, max: 500)
#
# Run: 1451, exploration: 0.05, score: 145
# Scores: (min: 11, avg: 190.64, max: 500)
#
# Run: 1452, exploration: 0.05, score: 211
# Scores: (min: 11, avg: 192.05, max: 500)
#
# Run: 1453, exploration: 0.05, score: 120
# Scores: (min: 11, avg: 193.07, max: 500)
#
# Run: 1454, exploration: 0.05, score: 500
# Scores: (min: 11, avg: 197.94, max: 500)
#
# Solved in 1354 runs, 1454 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-7-d781f5c70a74> in cartpole()
#      86             if terminal:
#      87                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 88                 score_logger.add_score(step, run)
#      89                 break
#      90             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# The cartpole problem is a pole attached to a cart so it can freely pivot, with the goal of the agent moving the cart left or right to swing the pole up straight (at least in robotic versions) and keep it up straight by keeping it moving left or right. The states are the movement (velocity) of the cart (left or right), the angle of the pole, the angular velocity of the pole, and the position of the cart.
#
# In this case it uses a Deep Q Neural Network algorithm (DQN). The replay function is important because it needs to remember past tries and not get stuck in a rut, so to speak, so it samples from them randomly
#
# This implementation uses a fairly simple neural network, with a input layer size of 24, only a single hidden layer also of 24, and then an output layer. As mentioned, the NN has the advantage of allowing remembering past tries.
#
# Increasing the learning rate (doubling in my experience, from .001 to .002) drastically increased how many runs needed to solve the problem. I believe this is because it focused too much on learning instead of remembering past trials.
#
# PilcoLearner. (2011, May 26). Cart-Pole swing-up [Video]. YouTube. https://www.youtube.com/watch?v=XiigTGKZfks
#
# PyLessons. (n.d.). Introduction to Reinforcement Learning
# https://pylessons.com/CartPole-reinforcement-learning
